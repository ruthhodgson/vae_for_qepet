# %% [markdown]
# <a href="https://colab.research.google.com/github/mw2304/SummerProject2026/blob/main/combined_mlp_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Annihilation Position Reconstruction — Comparing different MLP models

# %% [markdown]
# ## 0. Shared setup
#
# Both models are trained on features derived from the exact same subset of events, so the data loading and event selection happens once here.

# %%
# %pip install uproot
# %pip install awkward_pandas
# Out:
# Collecting uproot
#   Downloading uproot-5.7.6-py3-none-any.whl.metadata (36 kB)
# Collecting awkward>=2.8.2 (from uproot)
#   Downloading awkward-2.13.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: cramjam>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from uproot) (2.12.0)
# Requirement already satisfied: fsspec!=2026.2.0 in /usr/local/lib/python3.13/dist-packages (from uproot) (2025.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from uproot) (2.1.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from uproot) (26.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.13/dist-packages (from uproot) (4.0.1)
# Collecting awkward-cpp==56 (from awkward>=2.8.2->uproot)
#   Downloading awkward_cpp-56-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Downloading uproot-5.7.6-py3-none-any.whl (405 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.8/405.8 kB 13.4 MB/s eta 0:00:00
# Downloading awkward-2.13.0-py3-none-any.whl (990 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.1/990.1 kB 48.2 MB/s eta 0:00:00
# Downloading awkward_cpp-56-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (698 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.7/698.7 kB 54.8 MB/s eta 0:00:00
# Installing collected packages: awkward-cpp, awkward, uproot
# Successfully installed awkward-2.13.0 awkward-cpp-56 uproot-5.7.6
# Collecting awkward_pandas
#   Downloading awkward_pandas-2023.8.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: awkward>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from awkward_pandas) (2.13.0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.13/dist-packages (from awkward_pandas) (2.2.3)
# Requirement already satisfied: awkward-cpp==56 in /usr/local/lib/python3.13/dist-packages (from awkward>=2.0.0->awkward_pandas) (56)
# Requirement already satisfied: fsspec>=2022.11.0 in /usr/local/lib/python3.13/dist-packages (from awkward>=2.0.0->awkward_pandas) (2025.3.0)
# Requirement already satisfied: numpy>=1.21.3 in /usr/local/lib/python3.13/dist-packages (from awkward>=2.0.0->awkward_pandas) (2.1.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from awkward>=2.0.0->awkward_pandas) (26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.2->awkward_pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.2->awkward_pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.2->awkward_pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2->awkward_pandas) (1.17.0)
# Downloading awkward_pandas-2023.8.0-py3-none-any.whl (11 kB)
# Installing collected packages: awkward_pandas
# Successfully installed awkward_pandas-2023.8.0

# %%
import numpy as np
import pandas as pd
import uproot
import os

import matplotlib.pyplot as plt

import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score

RANDOM_STATE = 42

print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.20.0

# %% [markdown]
# ### 0.1 Load the event data

# %%
ROOT_FILE = "augmerged.root"

file = uproot.open(ROOT_FILE)
print(file.keys())

tree = file["ThreeG_NCS"]
print(tree.keys())

branches = [
    "RunID", "EventID",
    "GammaIndex", "NGammas",
    "X_mm", "Y_mm", "Z_mm",
    "EnergyDeposit_keV", "PreEnergy_keV", "PostEnergy_keV",
    "AnnihilX_mm", "AnnihilY_mm", "AnnihilZ_mm",
]

df = tree.arrays(branches, library="pd")
df.head()
# Out:
# ['TwoG_NCS;1', 'TwoG_PhantomSCS;1', 'TwoG_ScannerSCS;1', 'TwoG_PhantomSCS_ScannerSCS;1', 'TwoG_PhantomDCS;1', 'TwoG_ScannerDCS;1', 'TwoG_PhantomSCS_ScannerDCS;1', 'TwoG_PhantomDCS_ScannerSCS;1', 'TwoG_PhantomDCS_ScannerDCS;1', 'TwoG_MCS;1', 'TwoG_Excluded;1', 'ThreeG_NCS;1', 'ThreeG_ScannerSCS;1', 'ThreeG_ScannerDCS;1', 'ThreeG_ScannerTCS;1', 'ThreeG_MCS;1', 'ThreeG_Excluded;1', 'Run;1']
# ['RunID', 'EventID', 'NGammas', 'AnnihilX_mm', 'AnnihilY_mm', 'AnnihilZ_mm', 'GammaIndex', 'GammaTrackID', 'GammaParentID', 'HitIndex', 'VolumeID', 'VolumeName', 'ProcessID', 'ProcessName', 'EnergyDeposit_keV', 'PreEnergy_keV', 'PostEnergy_keV', 'X_mm', 'Y_mm', 'Z_mm', 'Theta_deg', 'Phi_deg', 'DeltaPhi01_deg', 'DeltaPhi02_deg', 'DeltaPhi12_deg']
#               RunID  EventID  GammaIndex  NGammas       X_mm       Y_mm  \
# 0  slurm_36283167_1       43           0        3  22.533781  45.725643
# 1  slurm_36283167_1       43           1        3 -19.154974 -41.295967
# 2  slurm_36283167_1       43           2        3  10.009033  22.802109
# 3  slurm_36283167_1       56           0        3  15.187184  14.526692
# 4  slurm_36283167_1       56           1        3   1.183054 -10.753192
#
#         Z_mm  EnergyDeposit_keV  PreEnergy_keV  PostEnergy_keV  AnnihilX_mm  \
# 0  -6.039716         187.380234     187.380234             0.0     3.079860
# 1  42.954437         471.598907     471.598907             0.0     3.079860
# 2 -44.240387         363.018677     363.018677             0.0     3.079860
# 3  46.622974         492.708618     492.708618             0.0    -0.369778
# 4 -51.622868         304.623718     304.623718             0.0    -0.369778
#
#    AnnihilY_mm  AnnihilZ_mm
# 0     6.565360    -6.969770
# 1     6.565360    -6.969770
# 2     6.565360    -6.969770
# 3     0.324251    -4.727468
# 4     0.324251    -4.727468

# %% [markdown]
# ### 0.2 Select a fixed-size subset of events
#
# Both models are trained on the same first 15,000 events, so any difference in results comes from the feature engineering / architecture / loss, not from seeing different data.

# %%
N_EVENTS = 15000

events = df[["RunID", "EventID"]].drop_duplicates()
events_subset = events.head(N_EVENTS)

df_subset = df.merge(events_subset, on=["RunID", "EventID"], how="inner")

print("Events selected:", len(events_subset))
print("Rows selected:  ", len(df_subset))
print("Events in subset:", df_subset.groupby(["RunID", "EventID"]).ngroups)
# Out:
# Events selected: 15000
# Rows selected:   45000
# Events in subset: 15000

# %% [markdown]
# ---
# ## 1. `mlp` — position + energy + distance features
#
# A plain MLP: two hidden layers of 100 units, trained with MAE loss directly on hit positions, hit energies, and the three pairwise hit-to-hit distances (15 input features). No plane information is used.

# %% [markdown]
# ### 1.1 Feature engineering

# %%
event_features_mlp = []
event_targets_mlp = []

for (run_id, event_id), event in df_subset.groupby(["RunID", "EventID"]):

    event = event.sort_values("GammaIndex")

    if len(event) < 3:
        continue
    event = event.iloc[:3]

    # --- positions and energies ---
    hit1 = event.iloc[0][["X_mm", "Y_mm", "Z_mm"]].values.astype(float)
    hit2 = event.iloc[1][["X_mm", "Y_mm", "Z_mm"]].values.astype(float)
    hit3 = event.iloc[2][["X_mm", "Y_mm", "Z_mm"]].values.astype(float)

    e1 = float(event.iloc[0]["EnergyDeposit_keV"])
    e2 = float(event.iloc[1]["EnergyDeposit_keV"])
    e3 = float(event.iloc[2]["EnergyDeposit_keV"])

    # --- pairwise distances ---
    d12 = np.linalg.norm(hit1 - hit2)
    d13 = np.linalg.norm(hit1 - hit3)
    d23 = np.linalg.norm(hit2 - hit3)

    # --- 15 input features ---
    features = np.concatenate([
        hit1, [e1],
        hit2, [e2],
        hit3, [e3],
        [d12, d13, d23],
    ])
    event_features_mlp.append(features)

    target = event[["AnnihilX_mm", "AnnihilY_mm", "AnnihilZ_mm"]].iloc[0].values.astype(float)
    event_targets_mlp.append(target)

X_mlp = np.array(event_features_mlp)
y_mlp = np.array(event_targets_mlp)

print("X_mlp shape:", X_mlp.shape)
print("y_mlp shape:", y_mlp.shape)
# Out:
# X_mlp shape: (15000, 15)
# y_mlp shape: (15000, 3)

# %% [markdown]
# ### 1.2 Train / validation / test split, then scale

# %%
X_train_mlp, X_temp_mlp, y_train_mlp, y_temp_mlp = train_test_split(
    X_mlp, y_mlp, test_size=0.20, random_state=RANDOM_STATE
)

X_val_mlp, X_test_mlp, y_val_mlp, y_test_mlp = train_test_split(
    X_temp_mlp, y_temp_mlp, test_size=0.33, random_state=RANDOM_STATE
)

print(f"Train: {len(X_train_mlp)}  Val: {len(X_val_mlp)}  Test: {len(X_test_mlp)}")
# Out:
# Train: 12000  Val: 2010  Test: 990

# %%
input_scaler_mlp = StandardScaler()

X_train_scaled_mlp = input_scaler_mlp.fit_transform(X_train_mlp)
X_val_scaled_mlp = input_scaler_mlp.transform(X_val_mlp)
X_test_scaled_mlp = input_scaler_mlp.transform(X_test_mlp)

target_scaler_mlp = StandardScaler()

y_train_scaled_mlp = target_scaler_mlp.fit_transform(y_train_mlp)
y_val_scaled_mlp = target_scaler_mlp.transform(y_val_mlp)
y_test_scaled_mlp = target_scaler_mlp.transform(y_test_mlp)

# %% [markdown]
# ### 1.3 Build, compile and train the model

# %%
model_mlp = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(15,)),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(3),
])

model_mlp.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="mae",
    metrics=["mae"],
)

model_mlp.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 100)            │         1,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           303 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,003 (46.89 KB)
#  Trainable params: 12,003 (46.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_mlp = model_mlp.fit(
    X_train_scaled_mlp,
    y_train_scaled_mlp,
    validation_data=(X_val_scaled_mlp, y_val_scaled_mlp),
    epochs=100,
    batch_size=32,
    verbose=1,
)
# Out:
# Epoch 1/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.8292 - mae: 0.8292 - val_loss: 0.7863 - val_mae: 0.7863
# Epoch 2/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7817 - mae: 0.7817 - val_loss: 0.7503 - val_mae: 0.7503
# Epoch 3/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7371 - mae: 0.7371 - val_loss: 0.7292 - val_mae: 0.7292
# Epoch 4/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.6979 - mae: 0.6979 - val_loss: 0.7004 - val_mae: 0.7004
# Epoch 5/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6652 - mae: 0.6652 - val_loss: 0.6713 - val_mae: 0.6713
# Epoch 6/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6420 - mae: 0.6420 - val_loss: 0.6753 - val_mae: 0.6753
# Epoch 7/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6194 - mae: 0.6194 - val_loss: 0.6251 - val_mae: 0.6251
# Epoch 8/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6004 - mae: 0.6004 - val_loss: 0.6063 - val_mae: 0.6063
# Epoch 9/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5866 - mae: 0.5866 - val_loss: 0.6088 - val_mae: 0.6088
# Epoch 10/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.5723 - mae: 0.5723 - val_loss: 0.5903 - val_mae: 0.5903
# Epoch 11/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.5601 - mae: 0.5601 - val_loss: 0.5707 - val_mae: 0.5707
# Epoch 12/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.5493 - mae: 0.5493 - val_loss: 0.5706 - val_mae: 0.5706
# Epoch 13/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5389 - mae: 0.5389 - val_loss: 0.5694 - val_mae: 0.5694
# Epoch 14/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5303 - mae: 0.5303 - val_loss: 0.5594 - val_mae: 0.5594
# Epoch 15/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5206 - mae: 0.5206 - val_loss: 0.5434 - val_mae: 0.5434
# Epoch 16/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5095 - mae: 0.5095 - val_loss: 0.5341 - val_mae: 0.5341
# Epoch 17/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5026 - mae: 0.5026 - val_loss: 0.5327 - val_mae: 0.5327
# Epoch 18/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4974 - mae: 0.4974 - val_loss: 0.5234 - val_mae: 0.5234
# Epoch 19/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4900 - mae: 0.4900 - val_loss: 0.5140 - val_mae: 0.5140
# Epoch 20/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4850 - mae: 0.4850 - val_loss: 0.5121 - val_mae: 0.5121
# Epoch 21/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4816 - mae: 0.4816 - val_loss: 0.5049 - val_mae: 0.5049
# Epoch 22/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4732 - mae: 0.4732 - val_loss: 0.5070 - val_mae: 0.5070
# Epoch 23/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4692 - mae: 0.4692 - val_loss: 0.5023 - val_mae: 0.5023
# Epoch 24/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4648 - mae: 0.4648 - val_loss: 0.5092 - val_mae: 0.5092
# Epoch 25/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4599 - mae: 0.4599 - val_loss: 0.4944 - val_mae: 0.4944
# Epoch 26/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4550 - mae: 0.4550 - val_loss: 0.4851 - val_mae: 0.4851
# Epoch 27/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4529 - mae: 0.4529 - val_loss: 0.5025 - val_mae: 0.5025
# Epoch 28/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4478 - mae: 0.4478 - val_loss: 0.4789 - val_mae: 0.4789
# Epoch 29/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4433 - mae: 0.4433 - val_loss: 0.4831 - val_mae: 0.4831
# Epoch 30/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4398 - mae: 0.4398 - val_loss: 0.4801 - val_mae: 0.4801
# Epoch 31/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4332 - mae: 0.4332 - val_loss: 0.4746 - val_mae: 0.4746
# Epoch 32/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4319 - mae: 0.4319 - val_loss: 0.4900 - val_mae: 0.4900
# Epoch 33/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4266 - mae: 0.4266 - val_loss: 0.4697 - val_mae: 0.4697
# Epoch 34/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4281 - mae: 0.4281 - val_loss: 0.4720 - val_mae: 0.4720
# Epoch 35/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4221 - mae: 0.4221 - val_loss: 0.4611 - val_mae: 0.4611
# Epoch 36/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4196 - mae: 0.4196 - val_loss: 0.4603 - val_mae: 0.4603
# Epoch 37/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4195 - mae: 0.4195 - val_loss: 0.4618 - val_mae: 0.4618
# Epoch 38/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4147 - mae: 0.4147 - val_loss: 0.4585 - val_mae: 0.4585
# Epoch 39/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4122 - mae: 0.4122 - val_loss: 0.4581 - val_mae: 0.4581
# Epoch 40/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4082 - mae: 0.4082 - val_loss: 0.4618 - val_mae: 0.4618
# Epoch 41/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4047 - mae: 0.4047 - val_loss: 0.4622 - val_mae: 0.4622
# Epoch 42/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4052 - mae: 0.4052 - val_loss: 0.4615 - val_mae: 0.4615
# Epoch 43/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4011 - mae: 0.4011 - val_loss: 0.4573 - val_mae: 0.4573
# Epoch 44/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3993 - mae: 0.3993 - val_loss: 0.4449 - val_mae: 0.4449
# Epoch 45/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3960 - mae: 0.3960 - val_loss: 0.4552 - val_mae: 0.4552
# Epoch 46/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3949 - mae: 0.3949 - val_loss: 0.4696 - val_mae: 0.4696
# Epoch 47/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3937 - mae: 0.3937 - val_loss: 0.4453 - val_mae: 0.4453
# Epoch 48/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3879 - mae: 0.3879 - val_loss: 0.4437 - val_mae: 0.4437
# Epoch 49/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3886 - mae: 0.3886 - val_loss: 0.4432 - val_mae: 0.4432
# Epoch 50/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3852 - mae: 0.3852 - val_loss: 0.4472 - val_mae: 0.4472
# Epoch 51/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3835 - mae: 0.3835 - val_loss: 0.4465 - val_mae: 0.4465
# Epoch 52/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.3841 - mae: 0.3841 - val_loss: 0.4487 - val_mae: 0.4487
# Epoch 53/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3798 - mae: 0.3798 - val_loss: 0.4402 - val_mae: 0.4402
# Epoch 54/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3779 - mae: 0.3779 - val_loss: 0.4491 - val_mae: 0.4491
# Epoch 55/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3774 - mae: 0.3774 - val_loss: 0.4404 - val_mae: 0.4404
# Epoch 56/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3743 - mae: 0.3743 - val_loss: 0.4475 - val_mae: 0.4475
# Epoch 57/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3772 - mae: 0.3772 - val_loss: 0.4371 - val_mae: 0.4371
# Epoch 58/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3745 - mae: 0.3745 - val_loss: 0.4333 - val_mae: 0.4333
# Epoch 59/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3703 - mae: 0.3703 - val_loss: 0.4317 - val_mae: 0.4317
# Epoch 60/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3722 - mae: 0.3722 - val_loss: 0.4325 - val_mae: 0.4325
# Epoch 61/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3692 - mae: 0.3692 - val_loss: 0.4320 - val_mae: 0.4320
# Epoch 62/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3662 - mae: 0.3662 - val_loss: 0.4481 - val_mae: 0.4481
# Epoch 63/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.3660 - mae: 0.3660 - val_loss: 0.4239 - val_mae: 0.4239
# Epoch 64/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3633 - mae: 0.3633 - val_loss: 0.4289 - val_mae: 0.4289
# Epoch 65/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3641 - mae: 0.3641 - val_loss: 0.4259 - val_mae: 0.4259
# Epoch 66/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3609 - mae: 0.3609 - val_loss: 0.4275 - val_mae: 0.4275
# Epoch 67/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3591 - mae: 0.3591 - val_loss: 0.4167 - val_mae: 0.4167
# Epoch 68/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3619 - mae: 0.3619 - val_loss: 0.4274 - val_mae: 0.4274
# Epoch 69/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3594 - mae: 0.3594 - val_loss: 0.4231 - val_mae: 0.4231
# Epoch 70/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3580 - mae: 0.3580 - val_loss: 0.4329 - val_mae: 0.4329
# Epoch 71/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3546 - mae: 0.3546 - val_loss: 0.4181 - val_mae: 0.4181
# Epoch 72/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3514 - mae: 0.3514 - val_loss: 0.4204 - val_mae: 0.4204
# Epoch 73/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.3545 - mae: 0.3545 - val_loss: 0.4220 - val_mae: 0.4220
# Epoch 74/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.3510 - mae: 0.3510 - val_loss: 0.4226 - val_mae: 0.4226
# Epoch 75/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3509 - mae: 0.3509 - val_loss: 0.4160 - val_mae: 0.4160
# Epoch 76/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3499 - mae: 0.3499 - val_loss: 0.4204 - val_mae: 0.4204
# Epoch 77/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3507 - mae: 0.3507 - val_loss: 0.4312 - val_mae: 0.4312
# Epoch 78/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3487 - mae: 0.3487 - val_loss: 0.4207 - val_mae: 0.4207
# Epoch 79/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3450 - mae: 0.3450 - val_loss: 0.4184 - val_mae: 0.4184
# Epoch 80/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3468 - mae: 0.3468 - val_loss: 0.4188 - val_mae: 0.4188
# Epoch 81/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3449 - mae: 0.3449 - val_loss: 0.4074 - val_mae: 0.4074
# Epoch 82/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3438 - mae: 0.3438 - val_loss: 0.4119 - val_mae: 0.4119
# Epoch 83/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3418 - mae: 0.3418 - val_loss: 0.4212 - val_mae: 0.4212
# Epoch 84/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.3426 - mae: 0.3426 - val_loss: 0.4074 - val_mae: 0.4074
# Epoch 85/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3410 - mae: 0.3410 - val_loss: 0.4083 - val_mae: 0.4083
# Epoch 86/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3417 - mae: 0.3417 - val_loss: 0.4025 - val_mae: 0.4025
# Epoch 87/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3371 - mae: 0.3371 - val_loss: 0.4199 - val_mae: 0.4199
# Epoch 88/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3410 - mae: 0.3410 - val_loss: 0.4093 - val_mae: 0.4093
# Epoch 89/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3376 - mae: 0.3376 - val_loss: 0.4117 - val_mae: 0.4117
# Epoch 90/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3386 - mae: 0.3386 - val_loss: 0.4087 - val_mae: 0.4087
# Epoch 91/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3350 - mae: 0.3350 - val_loss: 0.4016 - val_mae: 0.4016
# Epoch 92/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3345 - mae: 0.3345 - val_loss: 0.4132 - val_mae: 0.4132
# Epoch 93/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3351 - mae: 0.3351 - val_loss: 0.4065 - val_mae: 0.4065
# Epoch 94/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.3349 - mae: 0.3349 - val_loss: 0.4105 - val_mae: 0.4105
# Epoch 95/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.3310 - mae: 0.3310 - val_loss: 0.4051 - val_mae: 0.4051
# Epoch 96/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3308 - mae: 0.3308 - val_loss: 0.4140 - val_mae: 0.4140
# Epoch 97/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3315 - mae: 0.3315 - val_loss: 0.4017 - val_mae: 0.4017
# Epoch 98/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3289 - mae: 0.3289 - val_loss: 0.4064 - val_mae: 0.4064
# Epoch 99/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3304 - mae: 0.3304 - val_loss: 0.4053 - val_mae: 0.4053
# Epoch 100/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3304 - mae: 0.3304 - val_loss: 0.3975 - val_mae: 0.3975

# %% [markdown]
# ### 1.4 Training curve

# %%
plt.figure(figsize=(8, 5))
plt.plot(history_mlp.history["loss"], label="Training loss")
plt.plot(history_mlp.history["val_loss"], label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("MAE")
plt.title("mlp — Training and Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 1.5 Predictions and reconstruction error

# %%
y_pred_scaled_mlp = model_mlp(X_test_scaled_mlp, training=False).numpy()
y_pred_mlp = target_scaler_mlp.inverse_transform(y_pred_scaled_mlp)

errors_mlp = np.linalg.norm(y_pred_mlp - y_test_mlp, axis=1)

mean_error_mlp = np.mean(errors_mlp)
median_error_mlp = np.median(errors_mlp)

x_mae_mlp = np.mean(np.abs(y_pred_mlp[:, 0] - y_test_mlp[:, 0]))
y_mae_mlp = np.mean(np.abs(y_pred_mlp[:, 1] - y_test_mlp[:, 1]))
z_mae_mlp = np.mean(np.abs(y_pred_mlp[:, 2] - y_test_mlp[:, 2]))

print(f"Mean error   : {mean_error_mlp:.3f} mm")
print(f"Median error : {median_error_mlp:.3f} mm")
print(f"X MAE        : {x_mae_mlp:.3f} mm")
print(f"Y MAE        : {y_mae_mlp:.3f} mm")
print(f"Z MAE        : {z_mae_mlp:.3f} mm")
# Out:
# Mean error   : 1.621 mm
# Median error : 1.422 mm
# X MAE        : 0.812 mm
# Y MAE        : 0.864 mm
# Z MAE        : 0.764 mm

# %% [markdown]
# ### 1.6 Visual diagnostics

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
coordinates = ["X", "Y", "Z"]

for i, coord in enumerate(coordinates):
    axes[i].scatter(y_test_mlp[:, i], y_pred_mlp[:, i], alpha=0.7)

    minimum = min(y_test_mlp[:, i].min(), y_pred_mlp[:, i].min())
    maximum = max(y_test_mlp[:, i].max(), y_pred_mlp[:, i].max())
    axes[i].plot([minimum, maximum], [minimum, maximum], linestyle="--")

    axes[i].set_xlabel(f"True {coord} (mm)")
    axes[i].set_ylabel(f"Predicted {coord} (mm)")
    axes[i].set_title(f"{coord}: True vs Predicted")
    axes[i].grid(True)

plt.tight_layout()
plt.suptitle("mlp — True vs Predicted Position", y=1.05)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(errors_mlp, bins=30)
plt.xlabel("3D Position Error (mm)")
plt.ylabel("Number of Events")
plt.title("mlp — Annihilation Position Error")
plt.grid(True)
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
projections = [(0, 1, "X", "Y"), (0, 2, "X", "Z"), (1, 2, "Y", "Z")]

for ax, (i, j, xname, yname) in zip(axes, projections):
    ax.scatter(y_test_mlp[:, i], y_test_mlp[:, j], marker="o", s=45, alpha=0.7, label="True")
    ax.scatter(y_pred_mlp[:, i], y_pred_mlp[:, j], marker="x", s=50, alpha=0.8, label="mlp")
    ax.set_xlabel(f"{xname} (mm)")
    ax.set_ylabel(f"{yname} (mm)")
    ax.set_title(f"{xname}{yname} Projection")
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.show()

# %%
n_events = min(6, len(X_test_mlp))

fig = plt.figure(figsize=(15, 10))

for i in range(n_events):
    ax = fig.add_subplot(2, 3, i + 1, projection="3d")

    hits = np.array([X_test_mlp[i, 0:3], X_test_mlp[i, 4:7], X_test_mlp[i, 8:11]])
    true_pos = y_test_mlp[i]
    pred_pos = y_pred_mlp[i]

    ax.scatter(hits[:, 0], hits[:, 1], hits[:, 2], s=80, marker="o", label="Gamma hits")
    ax.scatter(*true_pos, s=100, marker="*", label="True annihilation")
    ax.scatter(*pred_pos, s=100, marker="X", label="mlp prediction")

    for hit in hits:
        ax.plot([true_pos[0], hit[0]], [true_pos[1], hit[1]], [true_pos[2], hit[2]],
                linestyle="--", alpha=0.5)

    ax.plot([true_pos[0], pred_pos[0]], [true_pos[1], pred_pos[1]], [true_pos[2], pred_pos[2]],
            linestyle=":", linewidth=2)

    error = np.linalg.norm(pred_pos - true_pos)
    ax.set_title(f"Event {i + 1}\nReconstruction error = {error:.2f} mm")
    ax.set_xlabel("X (mm)")
    ax.set_ylabel("Y (mm)")
    ax.set_zlabel("Z (mm)")

handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper center", ncol=3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.7 Baseline comparison (naive mean-position predictor)

# %%
mean_position_mlp = np.mean(y_train_mlp, axis=0)
print("Mean annihilation position (train):", mean_position_mlp)

mean_predictions_mlp = np.tile(mean_position_mlp, (len(y_test_mlp), 1))
mean_errors_mlp = np.linalg.norm(mean_predictions_mlp - y_test_mlp, axis=1)

print("\nMean-position baseline — mean 3D error  :", np.mean(mean_errors_mlp), "mm")
print("Mean-position baseline — median 3D error:", np.median(mean_errors_mlp), "mm")

improvement_mlp = (np.mean(mean_errors_mlp) - mean_error_mlp) / np.mean(mean_errors_mlp) * 100
print(f"\nmlp mean 3D error   : {mean_error_mlp:.3f} mm")
print(f"Baseline mean 3D error: {np.mean(mean_errors_mlp):.3f} mm")
print(f"Improvement over baseline: {improvement_mlp:.1f}%")
# Out:
# Mean annihilation position (train): [ 1.82516059  3.00046503 -8.14236138]
#
# Mean-position baseline — mean 3D error  : 3.5481860379629215 mm
# Mean-position baseline — median 3D error: 3.6685539241921443 mm
#
# mlp mean 3D error   : 1.621 mm
# Baseline mean 3D error: 3.548 mm
# Improvement over baseline: 54.3%

# %% [markdown]
# ### 1.8 Summary

# %%
results_mlp = {
    "model": "mlp",
    "mae_x": x_mae_mlp,
    "mae_y": y_mae_mlp,
    "mae_z": z_mae_mlp,
    "mae_overall": mean_absolute_error(y_test_mlp, y_pred_mlp),
    "mean_3d_error_mm": mean_error_mlp,
    "median_3d_error_mm": median_error_mlp,
    "r2_overall": r2_score(y_test_mlp, y_pred_mlp),
    "improvement_over_mean_baseline_pct": improvement_mlp,
}

results_mlp
# Out:
# {'model': 'mlp',
#  'mae_x': np.float64(0.8120468849643143),
#  'mae_y': np.float64(0.8639871125528706),
#  'mae_z': np.float64(0.7637691940924134),
#  'mae_overall': 0.8132677305365328,
#  'mean_3d_error_mm': np.float64(1.6206744279007552),
#  'median_3d_error_mm': np.float64(1.4215627441990133),
#  'r2_overall': 0.731076441020465,
#  'improvement_over_mean_baseline_pct': np.float64(54.3238598382171)}

# %% [markdown]
# **What changed vs. the original `kerasMLP.ipynb`:**
# - Data loading and the 15,000-event subset selection moved to the shared Section 0.
# - Combined the two separate `%pip install` cells and removed empty placeholder cells.
# - Renamed variables with an `_mlp` suffix so this section can coexist with `pc_mlp` in the same notebook.
# - Removed the redundant re-computation of `mlp_errors` (identical to `errors_mlp`) in the baseline-comparison step.

# %% [markdown]
# ---
# ## 2. `pc_mlp` — plane-constrained MLP
#
# Same style of MLP, extended with three opening-angle features (18 inputs total) and trained with a **custom loss** that adds a penalty for predictions landing off the plane defined by the three detector hits:
#
# `total_loss = mae_loss + lambda_plane * plane_loss`
#
# Setting `lambda_plane = 0` recovers a plain MAE-only MLP — that variant is trained alongside the real plane-constrained model (`lambda_plane = 0.1`) as an internal baseline, so the effect of the plane term can be isolated directly.

# %% [markdown]
# ### 2.1 Feature engineering (+ opening angles, + event plane)

# %%
def build_event_arrays(df_events):
    """Turn the flat hit-level dataframe into per-event feature / target /
    plane arrays, keeping only events with 3 well-separated hits."""

    features_list = []
    targets_list = []
    plane_list = []

    for (run_id, event_id), event in df_events.groupby(["RunID", "EventID"]):
        event = event.sort_values("GammaIndex")

        if len(event) < 3:
            continue
        event = event.iloc[:3]

        hit1, hit2, hit3 = (
            event[["X_mm", "Y_mm", "Z_mm"]].iloc[i].values.astype(float)
            for i in range(3)
        )

        # --- event plane: point + unit normal ---
        v1 = hit2 - hit1
        v2 = hit3 - hit1
        normal = np.cross(v1, v2)
        normal_length = np.linalg.norm(normal)

        if normal_length < 1e-8:
            # Degenerate / near-collinear triangle: plane is undefined, skip.
            continue

        normal = normal / normal_length
        plane_point = hit1
        plane_list.append(np.concatenate([plane_point, normal]))

        # --- energies ---
        e1, e2, e3 = (float(event.iloc[i]["EnergyDeposit_keV"]) for i in range(3))

        # --- pairwise distances ---
        d12 = np.linalg.norm(hit1 - hit2)
        d13 = np.linalg.norm(hit1 - hit3)
        d23 = np.linalg.norm(hit2 - hit3)

        # --- opening angles ---
        def angle_at(vertex, a, b):
            va = a - vertex
            vb = b - vertex
            cos_angle = np.dot(va, vb) / (np.linalg.norm(va) * np.linalg.norm(vb) + 1e-8)
            return np.arccos(np.clip(cos_angle, -1.0, 1.0))

        angle1 = angle_at(hit1, hit2, hit3)
        angle2 = angle_at(hit2, hit1, hit3)
        angle3 = angle_at(hit3, hit1, hit2)

        features_list.append(np.concatenate(
            [hit1, [e1], hit2, [e2], hit3, [e3], [d12, d13, d23], [angle1, angle2, angle3]]
        ))

        target = event[["AnnihilX_mm", "AnnihilY_mm", "AnnihilZ_mm"]].iloc[0].values.astype(float)
        targets_list.append(target)

    return np.array(features_list), np.array(targets_list), np.array(plane_list)


X_pcmlp, y_pcmlp, plane_data_pcmlp = build_event_arrays(df_subset)

print("X_pcmlp shape:", X_pcmlp.shape)
print("y_pcmlp shape:", y_pcmlp.shape)
print("plane_data_pcmlp shape:", plane_data_pcmlp.shape)
# Out:
# X_pcmlp shape: (15000, 18)
# y_pcmlp shape: (15000, 3)
# plane_data_pcmlp shape: (15000, 6)

# %% [markdown]
# ### 2.2 Train / validation / test split, then scale

# %%
X_train_pcmlp, X_temp_pcmlp, y_train_pcmlp, y_temp_pcmlp, plane_train_pcmlp, plane_temp_pcmlp = train_test_split(
    X_pcmlp, y_pcmlp, plane_data_pcmlp, test_size=0.20, random_state=RANDOM_STATE
)

X_val_pcmlp, X_test_pcmlp, y_val_pcmlp, y_test_pcmlp, plane_val_pcmlp, plane_test_pcmlp = train_test_split(
    X_temp_pcmlp, y_temp_pcmlp, plane_temp_pcmlp, test_size=0.33, random_state=RANDOM_STATE
)

print(f"Train: {len(X_train_pcmlp)}  Val: {len(X_val_pcmlp)}  Test: {len(X_test_pcmlp)}")
# Out:
# Train: 12000  Val: 2010  Test: 990

# %%
input_scaler_pcmlp = StandardScaler()

X_train_scaled_pcmlp = input_scaler_pcmlp.fit_transform(X_train_pcmlp)
X_val_scaled_pcmlp = input_scaler_pcmlp.transform(X_val_pcmlp)
X_test_scaled_pcmlp = input_scaler_pcmlp.transform(X_test_pcmlp)

# %% [markdown]
# ### 2.3 Plane-constrained model with a custom `train_step`
#
# Two loss terms:
#
# - **`mae_loss`** — standard mean absolute error between predicted and true position.
# - **`plane_loss`** — mean squared *signed* distance of the predicted point from the event plane (dot product of `(y_pred - plane_point)` with the plane's unit normal). Since `y_pred` is produced inside the `GradientTape` context, this term is fully differentiable and pulls predictions towards the plane during training.
#
# The loss computation is shared between `train_step` and `test_step` via `_compute_losses`, so training and evaluation can never quietly drift apart.

# %%
class PlaneConstrainedMLP(tf.keras.Model):
    """MLP that regresses the 3D annihilation position, optionally penalised
    for predicting a point off the event plane.

    Set `lambda_plane=0.0` to disable the plane term entirely (plain MAE model).
    """

    def __init__(self, lambda_plane=1.0, hidden_units=100, name="plane_mlp"):
        super().__init__(name=name)
        self.lambda_plane = lambda_plane

        self.dense1 = tf.keras.layers.Dense(hidden_units, activation="relu")
        self.dense2 = tf.keras.layers.Dense(hidden_units, activation="relu")
        self.output_layer = tf.keras.layers.Dense(3)

        self.mae_tracker = tf.keras.metrics.Mean(name="mae")
        self.plane_tracker = tf.keras.metrics.Mean(name="plane_loss")
        self.total_tracker = tf.keras.metrics.Mean(name="loss")

    @property
    def metrics(self):
        # Listing these lets Keras auto-reset them at the start of every epoch.
        return [self.total_tracker, self.mae_tracker, self.plane_tracker]

    def call(self, x, training=False):
        x = self.dense1(x)
        x = self.dense2(x)
        return self.output_layer(x)

    def _compute_losses(self, x, y_true, plane_data, training):
        """Shared forward pass + loss computation for train_step/test_step."""

        plane_point = plane_data[:, 0:3]
        plane_normal = plane_data[:, 3:6]
        plane_normal = plane_normal / (
            tf.norm(plane_normal, axis=1, keepdims=True) + 1e-8
        )

        y_pred = self(x, training=training)

        mae_loss = tf.reduce_mean(tf.abs(y_true - y_pred))

        # Signed distance from the predicted point to the event plane.
        displacement = y_pred - plane_point
        distance_from_plane = tf.reduce_sum(displacement * plane_normal, axis=1)
        plane_loss = tf.reduce_mean(tf.square(distance_from_plane))

        total_loss = mae_loss + self.lambda_plane * plane_loss

        return y_pred, mae_loss, plane_loss, total_loss

    def _update_and_report(self, mae_loss, plane_loss, total_loss):
        self.mae_tracker.update_state(mae_loss)
        self.plane_tracker.update_state(plane_loss)
        self.total_tracker.update_state(total_loss)
        return {
            "loss": self.total_tracker.result(),
            "mae": self.mae_tracker.result(),
            "plane_loss": self.plane_tracker.result(),
        }

    def train_step(self, data):
        x, y_true, plane_data = data

        with tf.GradientTape() as tape:
            _, mae_loss, plane_loss, total_loss = self._compute_losses(
                x, y_true, plane_data, training=True
            )

        gradients = tape.gradient(total_loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))

        return self._update_and_report(mae_loss, plane_loss, total_loss)

    def test_step(self, data):
        x, y_true, plane_data = data
        _, mae_loss, plane_loss, total_loss = self._compute_losses(
            x, y_true, plane_data, training=False
        )
        return self._update_and_report(mae_loss, plane_loss, total_loss)

# %% [markdown]
# ### 2.4 Build the datasets, and two models to compare

# %%
BATCH_SIZE = 32
EPOCHS = 50
LEARNING_RATE = 0.001
LAMBDA_PLANE = 0.1  # weight of the plane-constraint term for pc_mlp

train_dataset_pcmlp = tf.data.Dataset.from_tensor_slices(
    (X_train_scaled_pcmlp, tf.cast(y_train_pcmlp, tf.float32), tf.cast(plane_train_pcmlp, tf.float32))
).shuffle(len(X_train_scaled_pcmlp)).batch(BATCH_SIZE)

val_dataset_pcmlp = tf.data.Dataset.from_tensor_slices(
    (X_val_scaled_pcmlp, tf.cast(y_val_pcmlp, tf.float32), tf.cast(plane_val_pcmlp, tf.float32))
).batch(BATCH_SIZE)

# %%
def make_model(lambda_plane, name):
    model = PlaneConstrainedMLP(lambda_plane=lambda_plane, name=name)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        run_eagerly=True,
    )
    return model

pcmlp_baseline = make_model(lambda_plane=0.0, name="pcmlp_baseline")
pc_mlp = make_model(lambda_plane=LAMBDA_PLANE, name="pc_mlp")

# %% [markdown]
# ### 2.5 Train both models

# %%
print("Training pcmlp_baseline (MAE-only) model...")
history_pcmlp_baseline = pcmlp_baseline.fit(
    train_dataset_pcmlp, epochs=EPOCHS, validation_data=val_dataset_pcmlp
)
# Out:
# Training pcmlp_baseline (MAE-only) model...
# Epoch 1/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - loss: 1.9715 - mae: 1.9715 - plane_loss: 5.9220 - val_loss: 1.7709 - val_mae: 1.7709 - val_plane_loss: 4.6162
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - loss: 1.7635 - mae: 1.7635 - plane_loss: 4.2693 - val_loss: 1.7243 - val_mae: 1.7243 - val_plane_loss: 4.1985
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - loss: 1.6947 - mae: 1.6947 - plane_loss: 3.7116 - val_loss: 1.6501 - val_mae: 1.6501 - val_plane_loss: 3.5563
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - loss: 1.6226 - mae: 1.6226 - plane_loss: 3.1870 - val_loss: 1.5942 - val_mae: 1.5942 - val_plane_loss: 3.1489
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 52ms/step - loss: 1.5490 - mae: 1.5490 - plane_loss: 2.6820 - val_loss: 1.5438 - val_mae: 1.5438 - val_plane_loss: 2.7516
# Epoch 6/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 53ms/step - loss: 1.4825 - mae: 1.4825 - plane_loss: 2.3388 - val_loss: 1.4623 - val_mae: 1.4623 - val_plane_loss: 2.3309
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 52ms/step - loss: 1.4269 - mae: 1.4269 - plane_loss: 2.0653 - val_loss: 1.4435 - val_mae: 1.4435 - val_plane_loss: 2.2140
# Epoch 8/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - loss: 1.3787 - mae: 1.3787 - plane_loss: 1.8733 - val_loss: 1.3778 - val_mae: 1.3778 - val_plane_loss: 1.8507
# Epoch 9/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - loss: 1.3389 - mae: 1.3389 - plane_loss: 1.7077 - val_loss: 1.3590 - val_mae: 1.3590 - val_plane_loss: 1.8353
# Epoch 10/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 40s 52ms/step - loss: 1.3019 - mae: 1.3019 - plane_loss: 1.5884 - val_loss: 1.3309 - val_mae: 1.3309 - val_plane_loss: 1.7853
# Epoch 11/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 1.2782 - mae: 1.2782 - plane_loss: 1.5300 - val_loss: 1.2905 - val_mae: 1.2905 - val_plane_loss: 1.5579
# Epoch 12/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 23s 61ms/step - loss: 1.2450 - mae: 1.2450 - plane_loss: 1.4331 - val_loss: 1.2695 - val_mae: 1.2695 - val_plane_loss: 1.5635
# Epoch 13/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 27s 72ms/step - loss: 1.2124 - mae: 1.2124 - plane_loss: 1.3313 - val_loss: 1.2384 - val_mae: 1.2384 - val_plane_loss: 1.4100
# Epoch 14/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - loss: 1.1909 - mae: 1.1909 - plane_loss: 1.2881 - val_loss: 1.2146 - val_mae: 1.2146 - val_plane_loss: 1.4332
# Epoch 15/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 1.1697 - mae: 1.1697 - plane_loss: 1.2353 - val_loss: 1.1935 - val_mae: 1.1935 - val_plane_loss: 1.2983
# Epoch 16/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 52ms/step - loss: 1.1473 - mae: 1.1473 - plane_loss: 1.1967 - val_loss: 1.1897 - val_mae: 1.1897 - val_plane_loss: 1.3136
# Epoch 17/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 1.1326 - mae: 1.1326 - plane_loss: 1.1727 - val_loss: 1.1606 - val_mae: 1.1606 - val_plane_loss: 1.1851
# Epoch 18/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - loss: 1.1113 - mae: 1.1113 - plane_loss: 1.1176 - val_loss: 1.1846 - val_mae: 1.1846 - val_plane_loss: 1.3933
# Epoch 19/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - loss: 1.0987 - mae: 1.0987 - plane_loss: 1.1238 - val_loss: 1.1525 - val_mae: 1.1525 - val_plane_loss: 1.2887
# Epoch 20/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 1.0860 - mae: 1.0860 - plane_loss: 1.0787 - val_loss: 1.1279 - val_mae: 1.1279 - val_plane_loss: 1.2017
# Epoch 21/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 52ms/step - loss: 1.0748 - mae: 1.0748 - plane_loss: 1.0571 - val_loss: 1.1088 - val_mae: 1.1088 - val_plane_loss: 1.1521
# Epoch 22/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 1.0580 - mae: 1.0580 - plane_loss: 1.0268 - val_loss: 1.1281 - val_mae: 1.1281 - val_plane_loss: 1.1724
# Epoch 23/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 51ms/step - loss: 1.0468 - mae: 1.0468 - plane_loss: 1.0043 - val_loss: 1.1083 - val_mae: 1.1083 - val_plane_loss: 1.1425
# Epoch 24/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 1.0414 - mae: 1.0414 - plane_loss: 0.9840 - val_loss: 1.0802 - val_mae: 1.0802 - val_plane_loss: 1.0385
# Epoch 25/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 52ms/step - loss: 1.0244 - mae: 1.0244 - plane_loss: 0.9411 - val_loss: 1.0893 - val_mae: 1.0893 - val_plane_loss: 1.1383
# Epoch 26/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 1.0206 - mae: 1.0206 - plane_loss: 0.9404 - val_loss: 1.0502 - val_mae: 1.0502 - val_plane_loss: 1.0030
# Epoch 27/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 52ms/step - loss: 1.0050 - mae: 1.0050 - plane_loss: 0.9218 - val_loss: 1.0532 - val_mae: 1.0532 - val_plane_loss: 1.0071
# Epoch 28/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 1.0001 - mae: 1.0001 - plane_loss: 0.9026 - val_loss: 1.0443 - val_mae: 1.0443 - val_plane_loss: 1.0075
# Epoch 29/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - loss: 0.9918 - mae: 0.9918 - plane_loss: 0.8851 - val_loss: 1.0364 - val_mae: 1.0364 - val_plane_loss: 0.9560
# Epoch 30/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 0.9800 - mae: 0.9800 - plane_loss: 0.8609 - val_loss: 1.0481 - val_mae: 1.0481 - val_plane_loss: 0.9943
# Epoch 31/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - loss: 0.9779 - mae: 0.9779 - plane_loss: 0.8636 - val_loss: 1.0377 - val_mae: 1.0377 - val_plane_loss: 0.9945
# Epoch 32/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 0.9704 - mae: 0.9704 - plane_loss: 0.8285 - val_loss: 1.0281 - val_mae: 1.0281 - val_plane_loss: 0.9591
# Epoch 33/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 52ms/step - loss: 0.9621 - mae: 0.9621 - plane_loss: 0.8393 - val_loss: 1.0204 - val_mae: 1.0204 - val_plane_loss: 0.9420
# Epoch 34/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - loss: 0.9518 - mae: 0.9518 - plane_loss: 0.8049 - val_loss: 1.0314 - val_mae: 1.0314 - val_plane_loss: 0.9977
# Epoch 35/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 51ms/step - loss: 0.9475 - mae: 0.9475 - plane_loss: 0.7862 - val_loss: 1.0198 - val_mae: 1.0198 - val_plane_loss: 0.9194
# Epoch 36/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 0.9426 - mae: 0.9426 - plane_loss: 0.7870 - val_loss: 1.0013 - val_mae: 1.0013 - val_plane_loss: 0.8645
# Epoch 37/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - loss: 0.9350 - mae: 0.9350 - plane_loss: 0.7626 - val_loss: 1.0026 - val_mae: 1.0026 - val_plane_loss: 0.9022
# Epoch 38/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 49ms/step - loss: 0.9347 - mae: 0.9347 - plane_loss: 0.7707 - val_loss: 1.0232 - val_mae: 1.0232 - val_plane_loss: 0.9904
# Epoch 39/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 51ms/step - loss: 0.9261 - mae: 0.9261 - plane_loss: 0.7468 - val_loss: 0.9897 - val_mae: 0.9897 - val_plane_loss: 0.8963
# Epoch 40/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 0.9177 - mae: 0.9177 - plane_loss: 0.7328 - val_loss: 1.0086 - val_mae: 1.0086 - val_plane_loss: 0.8712
# Epoch 41/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 0.9134 - mae: 0.9134 - plane_loss: 0.7256 - val_loss: 0.9897 - val_mae: 0.9897 - val_plane_loss: 0.8220
# Epoch 42/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 0.9062 - mae: 0.9062 - plane_loss: 0.7170 - val_loss: 0.9895 - val_mae: 0.9895 - val_plane_loss: 0.8894
# Epoch 43/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 51ms/step - loss: 0.9040 - mae: 0.9040 - plane_loss: 0.7037 - val_loss: 0.9692 - val_mae: 0.9692 - val_plane_loss: 0.8170
# Epoch 44/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 0.8959 - mae: 0.8959 - plane_loss: 0.6901 - val_loss: 0.9775 - val_mae: 0.9775 - val_plane_loss: 0.8314
# Epoch 45/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - loss: 0.8934 - mae: 0.8934 - plane_loss: 0.6845 - val_loss: 0.9472 - val_mae: 0.9472 - val_plane_loss: 0.8002
# Epoch 46/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 0.8873 - mae: 0.8873 - plane_loss: 0.6629 - val_loss: 0.9768 - val_mae: 0.9768 - val_plane_loss: 0.8434
# Epoch 47/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 0.8792 - mae: 0.8792 - plane_loss: 0.6750 - val_loss: 0.9503 - val_mae: 0.9503 - val_plane_loss: 0.7646
# Epoch 48/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 0.8776 - mae: 0.8776 - plane_loss: 0.6526 - val_loss: 0.9511 - val_mae: 0.9511 - val_plane_loss: 0.7573
# Epoch 49/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 22s 52ms/step - loss: 0.8724 - mae: 0.8724 - plane_loss: 0.6624 - val_loss: 0.9843 - val_mae: 0.9843 - val_plane_loss: 0.8689
# Epoch 50/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 0.8730 - mae: 0.8730 - plane_loss: 0.6583 - val_loss: 0.9439 - val_mae: 0.9439 - val_plane_loss: 0.7498

# %%
print("Training pc_mlp (plane-constrained) model...")
history_pc_mlp = pc_mlp.fit(
    train_dataset_pcmlp, epochs=EPOCHS, validation_data=val_dataset_pcmlp
)
# Out:
# Training pc_mlp (plane-constrained) model...
# Epoch 1/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 2.5637 - mae: 1.9753 - plane_loss: 5.8839 - val_loss: 2.1973 - val_mae: 1.7502 - val_plane_loss: 4.4706
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 2.1403 - mae: 1.7454 - plane_loss: 3.9489 - val_loss: 2.0356 - val_mae: 1.6730 - val_plane_loss: 3.6258
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 1.9711 - mae: 1.6565 - plane_loss: 3.1459 - val_loss: 1.9138 - val_mae: 1.6163 - val_plane_loss: 2.9752
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - loss: 1.8248 - mae: 1.5788 - plane_loss: 2.4599 - val_loss: 1.7982 - val_mae: 1.5565 - val_plane_loss: 2.4169
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 22s 50ms/step - loss: 1.7195 - mae: 1.5136 - plane_loss: 2.0586 - val_loss: 1.7084 - val_mae: 1.5007 - val_plane_loss: 2.0773
# Epoch 6/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 1.6265 - mae: 1.4531 - plane_loss: 1.7339 - val_loss: 1.6266 - val_mae: 1.4509 - val_plane_loss: 1.7575
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 53ms/step - loss: 1.5630 - mae: 1.4069 - plane_loss: 1.5613 - val_loss: 1.5809 - val_mae: 1.4156 - val_plane_loss: 1.6534
# Epoch 8/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 1.5042 - mae: 1.3647 - plane_loss: 1.3943 - val_loss: 1.5075 - val_mae: 1.3595 - val_plane_loss: 1.4804
# Epoch 9/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - loss: 1.4512 - mae: 1.3240 - plane_loss: 1.2725 - val_loss: 1.5301 - val_mae: 1.3816 - val_plane_loss: 1.4846
# Epoch 10/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - loss: 1.4098 - mae: 1.2908 - plane_loss: 1.1901 - val_loss: 1.4358 - val_mae: 1.3088 - val_plane_loss: 1.2701
# Epoch 11/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 1.3723 - mae: 1.2622 - plane_loss: 1.1008 - val_loss: 1.4125 - val_mae: 1.2950 - val_plane_loss: 1.1748
# Epoch 12/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - loss: 1.3400 - mae: 1.2361 - plane_loss: 1.0390 - val_loss: 1.3580 - val_mae: 1.2487 - val_plane_loss: 1.0925
# Epoch 13/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 49ms/step - loss: 1.3032 - mae: 1.2056 - plane_loss: 0.9764 - val_loss: 1.3415 - val_mae: 1.2327 - val_plane_loss: 1.0879
# Epoch 14/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - loss: 1.2767 - mae: 1.1831 - plane_loss: 0.9359 - val_loss: 1.3183 - val_mae: 1.2139 - val_plane_loss: 1.0441
# Epoch 15/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 1.2464 - mae: 1.1587 - plane_loss: 0.8773 - val_loss: 1.3188 - val_mae: 1.2123 - val_plane_loss: 1.0655
# Epoch 16/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 49ms/step - loss: 1.2247 - mae: 1.1396 - plane_loss: 0.8508 - val_loss: 1.3001 - val_mae: 1.1935 - val_plane_loss: 1.0665
# Epoch 17/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 1.2070 - mae: 1.1242 - plane_loss: 0.8282 - val_loss: 1.2714 - val_mae: 1.1717 - val_plane_loss: 0.9966
# Epoch 18/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 1.1800 - mae: 1.1014 - plane_loss: 0.7868 - val_loss: 1.2221 - val_mae: 1.1361 - val_plane_loss: 0.8595
# Epoch 19/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 49ms/step - loss: 1.1633 - mae: 1.0863 - plane_loss: 0.7698 - val_loss: 1.2135 - val_mae: 1.1271 - val_plane_loss: 0.8638
# Epoch 20/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 1.1403 - mae: 1.0669 - plane_loss: 0.7340 - val_loss: 1.1783 - val_mae: 1.0957 - val_plane_loss: 0.8258
# Epoch 21/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 1.1286 - mae: 1.0562 - plane_loss: 0.7244 - val_loss: 1.1879 - val_mae: 1.1026 - val_plane_loss: 0.8526
# Epoch 22/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 1.1082 - mae: 1.0382 - plane_loss: 0.6999 - val_loss: 1.1617 - val_mae: 1.0812 - val_plane_loss: 0.8053
# Epoch 23/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 1.0962 - mae: 1.0283 - plane_loss: 0.6792 - val_loss: 1.1834 - val_mae: 1.0942 - val_plane_loss: 0.8921
# Epoch 24/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 1.0796 - mae: 1.0132 - plane_loss: 0.6641 - val_loss: 1.1671 - val_mae: 1.0802 - val_plane_loss: 0.8694
# Epoch 25/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 1.0673 - mae: 1.0036 - plane_loss: 0.6371 - val_loss: 1.1362 - val_mae: 1.0553 - val_plane_loss: 0.8085
# Epoch 26/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 1.0592 - mae: 0.9957 - plane_loss: 0.6348 - val_loss: 1.1443 - val_mae: 1.0581 - val_plane_loss: 0.8617
# Epoch 27/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 1.0515 - mae: 0.9892 - plane_loss: 0.6230 - val_loss: 1.0952 - val_mae: 1.0233 - val_plane_loss: 0.7188
# Epoch 28/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 1.0306 - mae: 0.9715 - plane_loss: 0.5903 - val_loss: 1.0908 - val_mae: 1.0203 - val_plane_loss: 0.7053
# Epoch 29/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - loss: 1.0261 - mae: 0.9673 - plane_loss: 0.5885 - val_loss: 1.0847 - val_mae: 1.0129 - val_plane_loss: 0.7184
# Epoch 30/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 1.0135 - mae: 0.9564 - plane_loss: 0.5714 - val_loss: 1.0754 - val_mae: 1.0093 - val_plane_loss: 0.6614
# Epoch 31/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 1.0084 - mae: 0.9510 - plane_loss: 0.5747 - val_loss: 1.0589 - val_mae: 0.9936 - val_plane_loss: 0.6536
# Epoch 32/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - loss: 0.9985 - mae: 0.9429 - plane_loss: 0.5558 - val_loss: 1.0605 - val_mae: 0.9911 - val_plane_loss: 0.6942
# Epoch 33/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 49ms/step - loss: 0.9900 - mae: 0.9355 - plane_loss: 0.5447 - val_loss: 1.0765 - val_mae: 1.0028 - val_plane_loss: 0.7370
# Epoch 34/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - loss: 0.9753 - mae: 0.9225 - plane_loss: 0.5285 - val_loss: 1.0680 - val_mae: 0.9969 - val_plane_loss: 0.7113
# Epoch 35/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - loss: 0.9730 - mae: 0.9205 - plane_loss: 0.5247 - val_loss: 1.0650 - val_mae: 0.9961 - val_plane_loss: 0.6892
# Epoch 36/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 0.9651 - mae: 0.9134 - plane_loss: 0.5166 - val_loss: 1.0485 - val_mae: 0.9813 - val_plane_loss: 0.6724
# Epoch 37/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 49ms/step - loss: 0.9592 - mae: 0.9086 - plane_loss: 0.5067 - val_loss: 1.0372 - val_mae: 0.9708 - val_plane_loss: 0.6643
# Epoch 38/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - loss: 0.9549 - mae: 0.9043 - plane_loss: 0.5058 - val_loss: 1.0342 - val_mae: 0.9680 - val_plane_loss: 0.6617
# Epoch 39/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 0.9412 - mae: 0.8929 - plane_loss: 0.4825 - val_loss: 0.9975 - val_mae: 0.9389 - val_plane_loss: 0.5863
# Epoch 40/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - loss: 0.9384 - mae: 0.8896 - plane_loss: 0.4878 - val_loss: 0.9962 - val_mae: 0.9364 - val_plane_loss: 0.5979
# Epoch 41/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - loss: 0.9268 - mae: 0.8792 - plane_loss: 0.4753 - val_loss: 0.9993 - val_mae: 0.9394 - val_plane_loss: 0.5990
# Epoch 42/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 0.9202 - mae: 0.8739 - plane_loss: 0.4629 - val_loss: 1.0368 - val_mae: 0.9684 - val_plane_loss: 0.6842
# Epoch 43/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - loss: 0.9206 - mae: 0.8736 - plane_loss: 0.4701 - val_loss: 0.9974 - val_mae: 0.9399 - val_plane_loss: 0.5750
# Epoch 44/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 0.9104 - mae: 0.8657 - plane_loss: 0.4473 - val_loss: 0.9773 - val_mae: 0.9235 - val_plane_loss: 0.5375
# Epoch 45/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 0.9032 - mae: 0.8587 - plane_loss: 0.4452 - val_loss: 0.9932 - val_mae: 0.9327 - val_plane_loss: 0.6052
# Epoch 46/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 0.9021 - mae: 0.8570 - plane_loss: 0.4514 - val_loss: 0.9949 - val_mae: 0.9337 - val_plane_loss: 0.6124
# Epoch 47/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - loss: 0.8891 - mae: 0.8472 - plane_loss: 0.4187 - val_loss: 0.9889 - val_mae: 0.9260 - val_plane_loss: 0.6288
# Epoch 48/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - loss: 0.8871 - mae: 0.8446 - plane_loss: 0.4253 - val_loss: 0.9944 - val_mae: 0.9341 - val_plane_loss: 0.6029
# Epoch 49/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 51ms/step - loss: 0.8852 - mae: 0.8426 - plane_loss: 0.4255 - val_loss: 1.0178 - val_mae: 0.9538 - val_plane_loss: 0.6403
# Epoch 50/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 51ms/step - loss: 0.8820 - mae: 0.8395 - plane_loss: 0.4252 - val_loss: 0.9537 - val_mae: 0.8977 - val_plane_loss: 0.5599

# %% [markdown]
# ### 2.6 Training curves: pcmlp_baseline vs. pc_mlp

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(history_pcmlp_baseline.history["loss"], label="pcmlp_baseline - train")
axes[0].plot(history_pcmlp_baseline.history["val_loss"], label="pcmlp_baseline - val", linestyle="--")
axes[0].plot(history_pc_mlp.history["loss"], label="pc_mlp - train")
axes[0].plot(history_pc_mlp.history["val_loss"], label="pc_mlp - val", linestyle="--")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Total loss")
axes[0].set_title("Training and Validation Loss")
axes[0].legend()
axes[0].grid(True)

axes[1].plot(history_pcmlp_baseline.history["mae"], label="pcmlp_baseline - train")
axes[1].plot(history_pcmlp_baseline.history["val_mae"], label="pcmlp_baseline - val", linestyle="--")
axes[1].plot(history_pc_mlp.history["mae"], label="pc_mlp - train")
axes[1].plot(history_pc_mlp.history["val_mae"], label="pc_mlp - val", linestyle="--")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("MAE (mm)")
axes[1].set_title("Training and Validation Position MAE")
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.7 Test-set evaluation
#
# Predict with both models on the held-out test set, then compare:
# 1. Overall 3D reconstruction error (does the plane constraint actually help?)
# 2. Per-coordinate error
# 3. How close predictions actually land to their event plane

# %%
y_pred_pcmlp_baseline = pcmlp_baseline.predict(X_test_scaled_pcmlp)
y_pred_pc_mlp = pc_mlp.predict(X_test_scaled_pcmlp)

print("y_test_pcmlp shape:        ", y_test_pcmlp.shape)
print("y_pred_pcmlp_baseline shape:", y_pred_pcmlp_baseline.shape)
print("y_pred_pc_mlp shape:        ", y_pred_pc_mlp.shape)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# y_test_pcmlp shape:         (990, 3)
# y_pred_pcmlp_baseline shape: (990, 3)
# y_pred_pc_mlp shape:         (990, 3)

# %%
def summarise_error(name, y_true, y_pred):
    err = np.linalg.norm(y_pred - y_true, axis=1)
    return {
        "model": name,
        "mean_error_mm": np.mean(err),
        "median_error_mm": np.median(err),
        "std_error_mm": np.std(err),
        "max_error_mm": np.max(err),
    }

summary_pcmlp = pd.DataFrame([
    summarise_error("pcmlp_baseline (MAE only)", y_test_pcmlp, y_pred_pcmlp_baseline),
    summarise_error("pc_mlp (plane-constrained)", y_test_pcmlp, y_pred_pc_mlp),
]).set_index("model")

summary_pcmlp
# Out:
#                             mean_error_mm  median_error_mm  std_error_mm  \
# model
# pcmlp_baseline (MAE only)        1.859700         1.648332      1.058970
# pc_mlp (plane-constrained)       1.745533         1.570320      1.010014
#
#                             max_error_mm
# model
# pcmlp_baseline (MAE only)       8.100038
# pc_mlp (plane-constrained)      8.701125

# %%
reconstruction_error_pcmlp_baseline = np.linalg.norm(y_pred_pcmlp_baseline - y_test_pcmlp, axis=1)
reconstruction_error_pc_mlp = np.linalg.norm(y_pred_pc_mlp - y_test_pcmlp, axis=1)

plt.figure(figsize=(8, 5))
plt.hist(reconstruction_error_pcmlp_baseline, bins=40, alpha=0.6, label="pcmlp_baseline (MAE only)")
plt.hist(reconstruction_error_pc_mlp, bins=40, alpha=0.6, label="pc_mlp (plane-constrained)")
plt.xlabel("3D reconstruction error (mm)")
plt.ylabel("Number of events")
plt.title("Annihilation Position Reconstruction Error")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 2.8 Did the plane constraint actually pull predictions towards the plane?
#
# This checks the thing `plane_loss` was directly optimising: the perpendicular distance from each *predicted* point to its own event's plane, for both models. If the constraint is working, `pc_mlp` should show noticeably smaller plane-distances than `pcmlp_baseline`.

# %%
def distance_to_plane(y_pred, plane):
    plane_point = plane[:, 0:3]
    plane_normal = plane[:, 3:6]
    plane_normal = plane_normal / (
        np.linalg.norm(plane_normal, axis=1, keepdims=True) + 1e-8
    )
    displacement = y_pred - plane_point
    return np.abs(np.sum(displacement * plane_normal, axis=1))


plane_dist_pcmlp_baseline = distance_to_plane(y_pred_pcmlp_baseline, plane_test_pcmlp)
plane_dist_pc_mlp = distance_to_plane(y_pred_pc_mlp, plane_test_pcmlp)

print("pcmlp_baseline - mean/median distance to plane (mm):",
      np.mean(plane_dist_pcmlp_baseline), "/", np.median(plane_dist_pcmlp_baseline))
print("pc_mlp - mean/median distance to plane (mm):",
      np.mean(plane_dist_pc_mlp), "/", np.median(plane_dist_pc_mlp))
# Out:
# pcmlp_baseline - mean/median distance to plane (mm): 0.6863209014204144 / 0.5698797562901285
# pc_mlp - mean/median distance to plane (mm): 0.5615320826939143 / 0.4863634862679955

# %% [markdown]
# ### 2.9 Detailed diagnostics for `pc_mlp`

# %%
residuals_pcmlp = y_pred_pc_mlp - y_test_pcmlp

fig, axes = plt.subplots(1, 3, figsize=(16, 5))
coordinates = ["X", "Y", "Z"]

for i, coord in enumerate(coordinates):
    axes[i].scatter(y_test_pcmlp[:, i], y_pred_pc_mlp[:, i], alpha=0.5)

    min_val = min(y_test_pcmlp[:, i].min(), y_pred_pc_mlp[:, i].min())
    max_val = max(y_test_pcmlp[:, i].max(), y_pred_pc_mlp[:, i].max())
    axes[i].plot([min_val, max_val], [min_val, max_val], linestyle="--")

    axes[i].set_xlabel(f"True {coord} (mm)")
    axes[i].set_ylabel(f"Predicted {coord} (mm)")
    axes[i].set_title(f"{coord}: True vs Predicted")
    axes[i].grid(True)

plt.tight_layout()
plt.suptitle("pc_mlp — True vs Predicted Position", y=1.03)
plt.show()

print("X MAE:", np.mean(np.abs(residuals_pcmlp[:, 0])))
print("Y MAE:", np.mean(np.abs(residuals_pcmlp[:, 1])))
print("Z MAE:", np.mean(np.abs(residuals_pcmlp[:, 2])))
# Out:
# X MAE: 0.8740745175338228
# Y MAE: 0.8772357707513929
# Z MAE: 0.8442573898970479

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

for i, coord in enumerate(coordinates):
    axes[i].hist(residuals_pcmlp[:, i], bins=40)
    axes[i].axvline(0, linestyle="--")
    axes[i].set_xlabel(f"{coord} residual (mm)")
    axes[i].set_ylabel("Number of events")
    axes[i].set_title(f"{coord} Reconstruction Residuals")
    axes[i].grid(True)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(17, 5))
projections = [(0, 1, "X", "Y"), (0, 2, "X", "Z"), (1, 2, "Y", "Z")]

for ax, (i, j, xname, yname) in zip(axes, projections):
    ax.scatter(y_test_pcmlp[:, i], y_test_pcmlp[:, j], alpha=0.5, label="True")
    ax.scatter(y_pred_pc_mlp[:, i], y_pred_pc_mlp[:, j], alpha=0.5, label="Predicted")
    ax.set_xlabel(f"{xname} (mm)")
    ax.set_ylabel(f"{yname} (mm)")
    ax.set_title(f"{xname}-{yname} Projection")
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.show()

# %%
n_events = min(6, len(X_test_pcmlp))

fig = plt.figure(figsize=(15, 10))

for i in range(n_events):
    ax = fig.add_subplot(2, 3, i + 1, projection="3d")

    hits = np.array([X_test_pcmlp[i, 0:3], X_test_pcmlp[i, 4:7], X_test_pcmlp[i, 8:11]])
    true_pos = y_test_pcmlp[i]
    pred_pos = y_pred_pc_mlp[i]

    ax.scatter(hits[:, 0], hits[:, 1], hits[:, 2], s=80, marker="o", label="Gamma hits")
    ax.scatter(*true_pos, s=100, marker="*", label="True annihilation")
    ax.scatter(*pred_pos, s=100, marker="X", label="pc_mlp prediction")

    for hit in hits:
        ax.plot([true_pos[0], hit[0]], [true_pos[1], hit[1]], [true_pos[2], hit[2]],
                linestyle="--", alpha=0.5)

    ax.plot([true_pos[0], pred_pos[0]], [true_pos[1], pred_pos[1]], [true_pos[2], pred_pos[2]],
            linestyle=":", linewidth=2)

    error = np.linalg.norm(pred_pos - true_pos)
    ax.set_title(f"Event {i + 1}\nReconstruction error = {error:.2f} mm")
    ax.set_xlabel("X (mm)")
    ax.set_ylabel("Y (mm)")
    ax.set_zlabel("Z (mm)")

handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper center", ncol=3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.10 Baseline comparison (naive mean-position predictor)

# %%
mean_position_pcmlp = np.mean(y_train_pcmlp, axis=0)
print("Mean annihilation position (train):", mean_position_pcmlp)

mean_predictions_pcmlp = np.tile(mean_position_pcmlp, (len(y_test_pcmlp), 1))
mean_errors_pcmlp = np.linalg.norm(mean_predictions_pcmlp - y_test_pcmlp, axis=1)

print("\nMean-position baseline — mean 3D error  :", np.mean(mean_errors_pcmlp), "mm")
print("Mean-position baseline — median 3D error:", np.median(mean_errors_pcmlp), "mm")

improvement_pcmlp = (
    (np.mean(mean_errors_pcmlp) - np.mean(reconstruction_error_pc_mlp))
    / np.mean(mean_errors_pcmlp) * 100
)
print(f"\npc_mlp mean 3D error    : {np.mean(reconstruction_error_pc_mlp):.3f} mm")
print(f"Baseline mean 3D error : {np.mean(mean_errors_pcmlp):.3f} mm")
print(f"Improvement over baseline: {improvement_pcmlp:.1f}%")
# Out:
# Mean annihilation position (train): [ 1.82516059  3.00046503 -8.14236138]
#
# Mean-position baseline — mean 3D error  : 3.5481860379629215 mm
# Mean-position baseline — median 3D error: 3.6685539241921443 mm
#
# pc_mlp mean 3D error    : 1.746 mm
# Baseline mean 3D error : 3.548 mm
# Improvement over baseline: 50.8%

# %% [markdown]
# ### 2.11 Summary

# %%
results_pcmlp_baseline = {
    "model": "pcmlp_baseline (18 features, no plane loss)",
    "mean_3d_error_mm": np.mean(reconstruction_error_pcmlp_baseline),
    "median_3d_error_mm": np.median(reconstruction_error_pcmlp_baseline),
    "r2_overall": r2_score(y_test_pcmlp, y_pred_pcmlp_baseline),
    "mean_plane_distance_mm": np.mean(plane_dist_pcmlp_baseline),
}

results_pcmlp = {
    "model": "pc_mlp",
    "mae_x": np.mean(np.abs(residuals_pcmlp[:, 0])),
    "mae_y": np.mean(np.abs(residuals_pcmlp[:, 1])),
    "mae_z": np.mean(np.abs(residuals_pcmlp[:, 2])),
    "mae_overall": mean_absolute_error(y_test_pcmlp, y_pred_pc_mlp),
    "mean_3d_error_mm": np.mean(reconstruction_error_pc_mlp),
    "median_3d_error_mm": np.median(reconstruction_error_pc_mlp),
    "r2_overall": r2_score(y_test_pcmlp, y_pred_pc_mlp),
    "mean_plane_distance_mm": np.mean(plane_dist_pc_mlp),
    "improvement_over_mean_baseline_pct": improvement_pcmlp,
}

results_pcmlp
# Out:
# {'model': 'pc_mlp',
#  'mae_x': np.float64(0.8740745175338228),
#  'mae_y': np.float64(0.8772357707513929),
#  'mae_z': np.float64(0.8442573898970479),
#  'mae_overall': 0.8651892260607545,
#  'mean_3d_error_mm': np.float64(1.7455325437979377),
#  'median_3d_error_mm': np.float64(1.5703200722919715),
#  'r2_overall': 0.6922548535551024,
#  'mean_plane_distance_mm': np.float64(0.5615320826939143),
#  'improvement_over_mean_baseline_pct': np.float64(50.80493172787299)}

# %% [markdown]
# # Plane constrained via conversion

# %% [markdown]
# 3.1 Feature engineering

# %%
def build_event_arrays_2d(df_events):

    features_list = []
    targets_list = []
    plane_list = []

    for (run_id, event_id), event in df_events.groupby(
        ["RunID", "EventID"]
    ):

        event = event.sort_values("GammaIndex")

        if len(event) < 3:
            continue

        event = event.iloc[:3]

        hit1 = event[
            ["X_mm", "Y_mm", "Z_mm"]
        ].iloc[0].values.astype(float)

        hit2 = event[
            ["X_mm", "Y_mm", "Z_mm"]
        ].iloc[1].values.astype(float)

        hit3 = event[
            ["X_mm", "Y_mm", "Z_mm"]
        ].iloc[2].values.astype(float)

        v1 = hit2 - hit1
        v2 = hit3 - hit1

        normal = np.cross(v1, v2)
        normal_length = np.linalg.norm(normal)

        if normal_length < 1e-8:
            continue

        normal = normal / normal_length

        basis_u = v1 / (
            np.linalg.norm(v1) + 1e-8
        )

        basis_v = np.cross(normal, basis_u)

        basis_v = basis_v / (
            np.linalg.norm(basis_v) + 1e-8
        )

        plane_data = np.concatenate([
            hit1,
            normal,
            basis_u,
            basis_v
        ])

        plane_list.append(plane_data)

        energy1 = float(
            event.iloc[0]["EnergyDeposit_keV"]
        )

        energy2 = float(
            event.iloc[1]["EnergyDeposit_keV"]
        )

        energy3 = float(
            event.iloc[2]["EnergyDeposit_keV"]
        )

        d12 = np.linalg.norm(hit1 - hit2)
        d13 = np.linalg.norm(hit1 - hit3)
        d23 = np.linalg.norm(hit2 - hit3)

        def angle_at(vertex, a, b):

            va = a - vertex
            vb = b - vertex

            cos_angle = np.dot(va, vb) / (
                np.linalg.norm(va)
                * np.linalg.norm(vb)
                + 1e-8
            )

            return np.arccos(
                np.clip(cos_angle, -1.0, 1.0)
            )

        angle1 = angle_at(hit1, hit2, hit3)
        angle2 = angle_at(hit2, hit1, hit3)
        angle3 = angle_at(hit3, hit1, hit2)

        features = np.concatenate([
            hit1, [energy1],
            hit2, [energy2],
            hit3, [energy3],
            [d12, d13, d23],
            [angle1, angle2, angle3]
        ])

        features_list.append(features)

        target = event[
            [
                "AnnihilX_mm",
                "AnnihilY_mm",
                "AnnihilZ_mm"
            ]
        ].iloc[0].values.astype(float)

        targets_list.append(target)

    return (
        np.array(features_list),
        np.array(targets_list),
        np.array(plane_list)
    )


X_plane2d, y_plane2d, plane_data_plane2d = build_event_arrays_2d(
    df_subset
)

print("X_plane2d shape:", X_plane2d.shape)
print("y_plane2d shape:", y_plane2d.shape)
print("plane_data_plane2d shape:", plane_data_plane2d.shape)
# Out:
# X_plane2d shape: (15000, 18)
# y_plane2d shape: (15000, 3)
# plane_data_plane2d shape: (15000, 12)

# %% [markdown]
# 3.2 train/val/test split

# %%
X_train_plane2d, X_temp_plane2d, \
y_train_plane2d, y_temp_plane2d, \
plane_train_plane2d, plane_temp_plane2d = train_test_split(
    X_plane2d,
    y_plane2d,
    plane_data_plane2d,
    test_size=0.20,
    random_state=RANDOM_STATE
)

X_val_plane2d, X_test_plane2d, \
y_val_plane2d, y_test_plane2d, \
plane_val_plane2d, plane_test_plane2d = train_test_split(
    X_temp_plane2d,
    y_temp_plane2d,
    plane_temp_plane2d,
    test_size=0.33,
    random_state=RANDOM_STATE
)

print("Training:", X_train_plane2d.shape)
print("Validation:", X_val_plane2d.shape)
print("Test:", X_test_plane2d.shape)
# Out:
# Training: (12000, 18)
# Validation: (2010, 18)
# Test: (990, 18)

# %% [markdown]
# 3.3 scaling

# %%
input_scaler_plane2d = StandardScaler()

X_train_scaled_plane2d = input_scaler_plane2d.fit_transform(
    X_train_plane2d
)

X_val_scaled_plane2d = input_scaler_plane2d.transform(
    X_val_plane2d
)

X_test_scaled_plane2d = input_scaler_plane2d.transform(
    X_test_plane2d
)

# %% [markdown]
# 3.4 converting xyz targets into u,v

# %%
def xyz_to_uv_plane2d(y_xyz, plane_data):

    plane_point = plane_data[:, 0:3]
    basis_u = plane_data[:, 6:9]
    basis_v = plane_data[:, 9:12]

    displacement = y_xyz - plane_point

    u = np.sum(
        displacement * basis_u,
        axis=1
    )

    v = np.sum(
        displacement * basis_v,
        axis=1
    )

    return np.column_stack([u, v])


y_train_uv_plane2d = xyz_to_uv_plane2d(
    y_train_plane2d,
    plane_train_plane2d
)

y_val_uv_plane2d = xyz_to_uv_plane2d(
    y_val_plane2d,
    plane_val_plane2d
)

y_test_uv_plane2d = xyz_to_uv_plane2d(
    y_test_plane2d,
    plane_test_plane2d
)

print("Training UV:", y_train_uv_plane2d.shape)
print("Validation UV:", y_val_uv_plane2d.shape)
print("Test UV:", y_test_uv_plane2d.shape)
# Out:
# Training UV: (12000, 2)
# Validation UV: (2010, 2)
# Test UV: (990, 2)

# %% [markdown]
# 3.5 building the MLP

# %%
class Plane2DMLP(tf.keras.Model):

    def __init__(self, hidden_units=100):
        super().__init__()

        self.dense1 = tf.keras.layers.Dense(
            hidden_units,
            activation="relu"
        )

        self.dense2 = tf.keras.layers.Dense(
            hidden_units,
            activation="relu"
        )

        self.output_layer = tf.keras.layers.Dense(2)

    def call(self, x, training=False):

        x = self.dense1(x)
        x = self.dense2(x)

        return self.output_layer(x)

# %% [markdown]
# 3.6 compile

# %%
model_plane2d = Plane2DMLP(
    hidden_units=100
)

model_plane2d.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=0.001
    ),
    loss="mae",
    metrics=["mae"]
)

# %% [markdown]
# 3.7 train

# %%
history_plane2d = model_plane2d.fit(
    X_train_scaled_plane2d,
    y_train_uv_plane2d,
    validation_data=(
        X_val_scaled_plane2d,
        y_val_uv_plane2d
    ),
    epochs=100,
    batch_size=BATCH_SIZE,
    shuffle=True
)
# Out:
# Epoch 1/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 10.4342 - mae: 10.4342 - val_loss: 3.9449 - val_mae: 3.9449
# Epoch 2/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3.2022 - mae: 3.2022 - val_loss: 2.7939 - val_mae: 2.7939
# Epoch 3/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 2.4271 - mae: 2.4271 - val_loss: 2.3196 - val_mae: 2.3196
# Epoch 4/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 2.1170 - mae: 2.1170 - val_loss: 2.0735 - val_mae: 2.0735
# Epoch 5/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.9465 - mae: 1.9465 - val_loss: 1.9122 - val_mae: 1.9122
# Epoch 6/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.8137 - mae: 1.8137 - val_loss: 1.8150 - val_mae: 1.8150
# Epoch 7/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.7111 - mae: 1.7111 - val_loss: 1.7143 - val_mae: 1.7143
# Epoch 8/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.6298 - mae: 1.6298 - val_loss: 1.7419 - val_mae: 1.7419
# Epoch 9/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5534 - mae: 1.5534 - val_loss: 1.6533 - val_mae: 1.6533
# Epoch 10/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.5074 - mae: 1.5074 - val_loss: 1.5575 - val_mae: 1.5575
# Epoch 11/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.4411 - mae: 1.4411 - val_loss: 1.4890 - val_mae: 1.4890
# Epoch 12/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 1.4056 - mae: 1.4056 - val_loss: 1.4851 - val_mae: 1.4851
# Epoch 13/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 1.3726 - mae: 1.3726 - val_loss: 1.4197 - val_mae: 1.4197
# Epoch 14/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.3457 - mae: 1.3457 - val_loss: 1.3985 - val_mae: 1.3985
# Epoch 15/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.3202 - mae: 1.3202 - val_loss: 1.3460 - val_mae: 1.3460
# Epoch 16/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.3024 - mae: 1.3024 - val_loss: 1.3859 - val_mae: 1.3859
# Epoch 17/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.2651 - mae: 1.2651 - val_loss: 1.3105 - val_mae: 1.3105
# Epoch 18/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.2497 - mae: 1.2497 - val_loss: 1.2998 - val_mae: 1.2998
# Epoch 19/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.2418 - mae: 1.2418 - val_loss: 1.2791 - val_mae: 1.2791
# Epoch 20/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2139 - mae: 1.2139 - val_loss: 1.2773 - val_mae: 1.2773
# Epoch 21/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.2008 - mae: 1.2008 - val_loss: 1.2620 - val_mae: 1.2620
# Epoch 22/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.2032 - mae: 1.2032 - val_loss: 1.2397 - val_mae: 1.2397
# Epoch 23/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.1768 - mae: 1.1768 - val_loss: 1.2346 - val_mae: 1.2346
# Epoch 24/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.1551 - mae: 1.1551 - val_loss: 1.2338 - val_mae: 1.2338
# Epoch 25/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.1421 - mae: 1.1421 - val_loss: 1.2271 - val_mae: 1.2271
# Epoch 26/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 1.1347 - mae: 1.1347 - val_loss: 1.2974 - val_mae: 1.2974
# Epoch 27/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.1282 - mae: 1.1282 - val_loss: 1.2225 - val_mae: 1.2225
# Epoch 28/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.1210 - mae: 1.1210 - val_loss: 1.1879 - val_mae: 1.1879
# Epoch 29/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.1098 - mae: 1.1098 - val_loss: 1.2452 - val_mae: 1.2452
# Epoch 30/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.0898 - mae: 1.0898 - val_loss: 1.1950 - val_mae: 1.1950
# Epoch 31/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 1.0935 - mae: 1.0935 - val_loss: 1.1550 - val_mae: 1.1550
# Epoch 32/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.0715 - mae: 1.0715 - val_loss: 1.1459 - val_mae: 1.1459
# Epoch 33/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 1.0550 - mae: 1.0550 - val_loss: 1.1500 - val_mae: 1.1500
# Epoch 34/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.0642 - mae: 1.0642 - val_loss: 1.1431 - val_mae: 1.1431
# Epoch 35/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.0432 - mae: 1.0432 - val_loss: 1.1782 - val_mae: 1.1782
# Epoch 36/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.0335 - mae: 1.0335 - val_loss: 1.1465 - val_mae: 1.1465
# Epoch 37/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 1.0299 - mae: 1.0299 - val_loss: 1.1110 - val_mae: 1.1110
# Epoch 38/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.0161 - mae: 1.0161 - val_loss: 1.1171 - val_mae: 1.1171
# Epoch 39/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0103 - mae: 1.0103 - val_loss: 1.1117 - val_mae: 1.1117
# Epoch 40/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0124 - mae: 1.0124 - val_loss: 1.0721 - val_mae: 1.0721
# Epoch 41/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9992 - mae: 0.9992 - val_loss: 1.0766 - val_mae: 1.0766
# Epoch 42/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9954 - mae: 0.9954 - val_loss: 1.1043 - val_mae: 1.1043
# Epoch 43/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9826 - mae: 0.9826 - val_loss: 1.0792 - val_mae: 1.0792
# Epoch 44/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9817 - mae: 0.9817 - val_loss: 1.0709 - val_mae: 1.0709
# Epoch 45/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9724 - mae: 0.9724 - val_loss: 1.0614 - val_mae: 1.0614
# Epoch 46/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9745 - mae: 0.9745 - val_loss: 1.0520 - val_mae: 1.0520
# Epoch 47/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9616 - mae: 0.9616 - val_loss: 1.1372 - val_mae: 1.1372
# Epoch 48/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9546 - mae: 0.9546 - val_loss: 1.0568 - val_mae: 1.0568
# Epoch 49/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9488 - mae: 0.9488 - val_loss: 1.0556 - val_mae: 1.0556
# Epoch 50/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9338 - mae: 0.9338 - val_loss: 1.0468 - val_mae: 1.0468
# Epoch 51/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9270 - mae: 0.9270 - val_loss: 1.0233 - val_mae: 1.0233
# Epoch 52/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9270 - mae: 0.9270 - val_loss: 0.9890 - val_mae: 0.9890
# Epoch 53/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9246 - mae: 0.9246 - val_loss: 1.0143 - val_mae: 1.0143
# Epoch 54/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9223 - mae: 0.9223 - val_loss: 1.0268 - val_mae: 1.0268
# Epoch 55/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9114 - mae: 0.9114 - val_loss: 0.9980 - val_mae: 0.9980
# Epoch 56/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9091 - mae: 0.9091 - val_loss: 1.0578 - val_mae: 1.0578
# Epoch 57/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9010 - mae: 0.9010 - val_loss: 1.0573 - val_mae: 1.0573
# Epoch 58/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8903 - mae: 0.8903 - val_loss: 0.9950 - val_mae: 0.9950
# Epoch 59/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9023 - mae: 0.9023 - val_loss: 0.9995 - val_mae: 0.9995
# Epoch 60/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8848 - mae: 0.8848 - val_loss: 0.9984 - val_mae: 0.9984
# Epoch 61/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8716 - mae: 0.8716 - val_loss: 0.9415 - val_mae: 0.9415
# Epoch 62/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8804 - mae: 0.8804 - val_loss: 0.9708 - val_mae: 0.9708
# Epoch 63/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8735 - mae: 0.8735 - val_loss: 0.9796 - val_mae: 0.9796
# Epoch 64/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8702 - mae: 0.8702 - val_loss: 0.9982 - val_mae: 0.9982
# Epoch 65/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8626 - mae: 0.8626 - val_loss: 0.9556 - val_mae: 0.9556
# Epoch 66/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8619 - mae: 0.8619 - val_loss: 0.9846 - val_mae: 0.9846
# Epoch 67/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.8536 - mae: 0.8536 - val_loss: 0.9407 - val_mae: 0.9407
# Epoch 68/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8399 - mae: 0.8399 - val_loss: 1.0041 - val_mae: 1.0041
# Epoch 69/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8460 - mae: 0.8460 - val_loss: 1.0197 - val_mae: 1.0197
# Epoch 70/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8515 - mae: 0.8515 - val_loss: 0.9479 - val_mae: 0.9479
# Epoch 71/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8339 - mae: 0.8339 - val_loss: 0.9302 - val_mae: 0.9302
# Epoch 72/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8377 - mae: 0.8377 - val_loss: 0.9267 - val_mae: 0.9267
# Epoch 73/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8254 - mae: 0.8254 - val_loss: 1.0420 - val_mae: 1.0420
# Epoch 74/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8309 - mae: 0.8309 - val_loss: 0.9765 - val_mae: 0.9765
# Epoch 75/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8178 - mae: 0.8178 - val_loss: 0.9338 - val_mae: 0.9338
# Epoch 76/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8236 - mae: 0.8236 - val_loss: 0.9209 - val_mae: 0.9209
# Epoch 77/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8028 - mae: 0.8028 - val_loss: 0.8944 - val_mae: 0.8944
# Epoch 78/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.8113 - mae: 0.8113 - val_loss: 0.9469 - val_mae: 0.9469
# Epoch 79/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8079 - mae: 0.8079 - val_loss: 0.9133 - val_mae: 0.9133
# Epoch 80/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8086 - mae: 0.8086 - val_loss: 0.9155 - val_mae: 0.9155
# Epoch 81/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7958 - mae: 0.7958 - val_loss: 0.9230 - val_mae: 0.9230
# Epoch 82/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8035 - mae: 0.8035 - val_loss: 0.9044 - val_mae: 0.9044
# Epoch 83/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7940 - mae: 0.7940 - val_loss: 0.9015 - val_mae: 0.9015
# Epoch 84/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7989 - mae: 0.7989 - val_loss: 0.8843 - val_mae: 0.8843
# Epoch 85/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7794 - mae: 0.7794 - val_loss: 0.9027 - val_mae: 0.9027
# Epoch 86/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7783 - mae: 0.7783 - val_loss: 0.8826 - val_mae: 0.8826
# Epoch 87/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7996 - mae: 0.7996 - val_loss: 0.8646 - val_mae: 0.8646
# Epoch 88/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7798 - mae: 0.7798 - val_loss: 0.8916 - val_mae: 0.8916
# Epoch 89/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.7762 - mae: 0.7762 - val_loss: 0.8869 - val_mae: 0.8869
# Epoch 90/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7778 - mae: 0.7778 - val_loss: 0.8685 - val_mae: 0.8685
# Epoch 91/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7680 - mae: 0.7680 - val_loss: 0.9254 - val_mae: 0.9254
# Epoch 92/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7659 - mae: 0.7659 - val_loss: 0.8620 - val_mae: 0.8620
# Epoch 93/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7751 - mae: 0.7751 - val_loss: 0.9608 - val_mae: 0.9608
# Epoch 94/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7699 - mae: 0.7699 - val_loss: 0.8696 - val_mae: 0.8696
# Epoch 95/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7722 - mae: 0.7722 - val_loss: 0.9034 - val_mae: 0.9034
# Epoch 96/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7531 - mae: 0.7531 - val_loss: 0.8615 - val_mae: 0.8615
# Epoch 97/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7468 - mae: 0.7468 - val_loss: 0.8713 - val_mae: 0.8713
# Epoch 98/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7430 - mae: 0.7430 - val_loss: 0.8731 - val_mae: 0.8731
# Epoch 99/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.7530 - mae: 0.7530 - val_loss: 0.8785 - val_mae: 0.8785
# Epoch 100/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7448 - mae: 0.7448 - val_loss: 0.8667 - val_mae: 0.8667

# %% [markdown]
# 3.8 convert predictions back to x,y,z

# %%
def uv_to_xyz_plane2d(uv, plane_data):

    plane_point = plane_data[:, 0:3]
    basis_u = plane_data[:, 6:9]
    basis_v = plane_data[:, 9:12]

    u = uv[:, 0]
    v = uv[:, 1]

    xyz = (
        plane_point
        + u[:, None] * basis_u
        + v[:, None] * basis_v
    )

    return xyz

# %% [markdown]
# 3.9 prediction shape

# %%
uv_pred_plane2d = model_plane2d.predict(
    X_test_scaled_plane2d
)

xyz_pred_plane2d = uv_to_xyz_plane2d(
    uv_pred_plane2d,
    plane_test_plane2d
)

print("XYZ prediction shape:", xyz_pred_plane2d.shape)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# XYZ prediction shape: (990, 3)

# %% [markdown]
# 3.10.1 loss curves

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

plt.plot(
    history_plane2d.history["loss"],
    label="Training loss"
)

plt.plot(
    history_plane2d.history["val_loss"],
    label="Validation loss"
)

plt.xlabel("Epoch")
plt.ylabel("MAE (mm)")
plt.title("2D Plane MLP Training and Validation Loss")

plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# 3.10.2 X,Y,Z MAE

# %%
errors_plane2d = (
    xyz_pred_plane2d - y_test_plane2d
)

absolute_errors_plane2d = np.abs(
    errors_plane2d
)

x_mae_plane2d = np.mean(
    absolute_errors_plane2d[:, 0]
)

y_mae_plane2d = np.mean(
    absolute_errors_plane2d[:, 1]
)

z_mae_plane2d = np.mean(
    absolute_errors_plane2d[:, 2]
)

print("X MAE:", x_mae_plane2d, "mm")
print("Y MAE:", y_mae_plane2d, "mm")
print("Z MAE:", z_mae_plane2d, "mm")
# Out:
# X MAE: 0.6915007133043104 mm
# Y MAE: 0.6732069985067547 mm
# Z MAE: 0.6594766037548133 mm

# %%
plt.figure(figsize=(7, 5))

maes = [
    x_mae_plane2d,
    y_mae_plane2d,
    z_mae_plane2d
]

plt.bar(
    ["X", "Y", "Z"],
    maes
)

plt.ylabel("MAE (mm)")
plt.title("2D Plane MLP Coordinate MAE")

for i, value in enumerate(maes):
    plt.text(
        i,
        value + 0.02,
        f"{value:.3f}",
        ha="center"
    )

plt.grid(axis="y", alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# 3.10.3 3D recosntuction error

# %%
error_3d_plane2d = np.linalg.norm(
    errors_plane2d,
    axis=1
)

mean_error_plane2d = np.mean(
    error_3d_plane2d
)

median_error_plane2d = np.median(
    error_3d_plane2d
)

max_error_plane2d = np.max(
    error_3d_plane2d
)

std_error_plane2d = np.std(
    error_3d_plane2d
)

print("Mean error   :", f"{mean_error_plane2d:.3f}", "mm")
print("Median error :", f"{median_error_plane2d:.3f}", "mm")
print("Std error    :", f"{std_error_plane2d:.3f}", "mm")
print("Maximum error:", f"{max_error_plane2d:.3f}", "mm")
# Out:
# Mean error   : 1.344 mm
# Median error : 1.061 mm
# Std error    : 1.050 mm
# Maximum error: 8.021 mm

# %%
plt.figure(figsize=(8, 5))

plt.hist(
    error_3d_plane2d,
    bins=30
)

plt.axvline(
    mean_error_plane2d,
    linestyle="--",
    label=f"Mean = {mean_error_plane2d:.3f} mm"
)

plt.axvline(
    median_error_plane2d,
    linestyle=":",
    label=f"Median = {median_error_plane2d:.3f} mm"
)

plt.xlabel("3D reconstruction error (mm)")
plt.ylabel("Number of events")
plt.title("2D Plane MLP Reconstruction Error")

plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# 3.10.4 true vs predicted

# %%
figures = [
    ("X", 0),
    ("Y", 1),
    ("Z", 2)
]

for coordinate, index in figures:

    plt.figure(figsize=(6, 6))

    plt.scatter(
        y_test_plane2d[:, index],
        xyz_pred_plane2d[:, index],
        alpha=0.5
    )

    minimum = min(
        y_test_plane2d[:, index].min(),
        xyz_pred_plane2d[:, index].min()
    )

    maximum = max(
        y_test_plane2d[:, index].max(),
        xyz_pred_plane2d[:, index].max()
    )

    plt.plot(
        [minimum, maximum],
        [minimum, maximum],
        linestyle="--"
    )

    plt.xlabel(f"True {coordinate} (mm)")
    plt.ylabel(f"Predicted {coordinate} (mm)")
    plt.title(
        f"2D Plane MLP: True vs Predicted {coordinate}"
    )

    plt.grid(alpha=0.3)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# 3.10.5 3d reocnstucted positions

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(9, 7))

ax = fig.add_subplot(111, projection="3d")

ax.scatter(
    y_test_plane2d[:, 0],
    y_test_plane2d[:, 1],
    y_test_plane2d[:, 2],
    alpha=0.5,
    label="True"
)

ax.scatter(
    xyz_pred_plane2d[:, 0],
    xyz_pred_plane2d[:, 1],
    xyz_pred_plane2d[:, 2],
    alpha=0.5,
    label="2D MLP"
)

ax.set_xlabel("X (mm)")
ax.set_ylabel("Y (mm)")
ax.set_zlabel("Z (mm)")

ax.set_title(
    "True vs Reconstructed Annihilation Positions"
)

ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# 3.10.6 2d projections

# %%
projections = [
    (0, 1, "X", "Y"),
    (0, 2, "X", "Z"),
    (1, 2, "Y", "Z")
]

for i, j, xlabel, ylabel in projections:

    plt.figure(figsize=(7, 6))

    plt.scatter(
        y_test_plane2d[:, i],
        y_test_plane2d[:, j],
        alpha=0.5,
        label="True"
    )

    plt.scatter(
        xyz_pred_plane2d[:, i],
        xyz_pred_plane2d[:, j],
        alpha=0.5,
        label="2D MLP"
    )

    plt.xlabel(f"{xlabel} (mm)")
    plt.ylabel(f"{ylabel} (mm)")

    plt.title(
        f"Annihilation Position: {xlabel}-{ylabel} Projection"
    )

    plt.legend()
    plt.grid(alpha=0.3)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# 3.10.7 residuals

# %%
for coordinate, index in [
    ("X", 0),
    ("Y", 1),
    ("Z", 2)
]:

    plt.figure(figsize=(8, 5))

    plt.hist(
        errors_plane2d[:, index],
        bins=30
    )

    plt.axvline(
        0,
        linestyle="--"
    )

    plt.xlabel(f"{coordinate} residual (mm)")
    plt.ylabel("Number of events")
    plt.title(
        f"2D Plane MLP {coordinate} Reconstruction Residuals"
    )

    plt.grid(alpha=0.3)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# 3.10.8 summary

# %%
print("2D PLANE MLP PERFORMANCE")

print(f"Mean 3D error   : {mean_error_plane2d:.3f} mm")
print(f"Median 3D error : {median_error_plane2d:.3f} mm")
print(f"Std 3D error    : {std_error_plane2d:.3f} mm")
print(f"Maximum error   : {max_error_plane2d:.3f} mm")

print()

print(f"X MAE           : {x_mae_plane2d:.3f} mm")
print(f"Y MAE           : {y_mae_plane2d:.3f} mm")
print(f"Z MAE           : {z_mae_plane2d:.3f} mm")

print()


print("PLANE CONSTRAINT")

plane_points = plane_test_plane2d[:, 0:3]
plane_normals = plane_test_plane2d[:, 3:6]

plane_distances_plane2d = np.abs(
    np.sum(
        (xyz_pred_plane2d - plane_points)
        * plane_normals,
        axis=1
    )
)

print(
    f"Mean plane distance   : "
    f"{np.mean(plane_distances_plane2d):.6f} mm"
)

print(
    f"Median plane distance : "
    f"{np.median(plane_distances_plane2d):.6f} mm"
)

print(
    f"Maximum plane distance: "
    f"{np.max(plane_distances_plane2d):.6f} mm"
)
# Out:
# 2D PLANE MLP PERFORMANCE
# Mean 3D error   : 1.344 mm
# Median 3D error : 1.061 mm
# Std 3D error    : 1.050 mm
# Maximum error   : 8.021 mm
#
# X MAE           : 0.692 mm
# Y MAE           : 0.673 mm
# Z MAE           : 0.659 mm
#
# PLANE CONSTRAINT
# Mean plane distance   : 0.000000 mm
# Median plane distance : 0.000000 mm
# Maximum plane distance: 0.000000 mm

# %% [markdown]
# 3.10.9 comparing to baseline mean model

# %%
mean_position_plane2d = np.mean(
    y_train_plane2d,
    axis=0
)

print(
    "Mean annihilation position (train):",
    mean_position_plane2d
)

mean_predictions_plane2d = np.tile(
    mean_position_plane2d,
    (len(y_test_plane2d), 1)
)

mean_errors_plane2d = np.linalg.norm(
    mean_predictions_plane2d - y_test_plane2d,
    axis=1
)

baseline_mean_plane2d = np.mean(
    mean_errors_plane2d
)

baseline_median_plane2d = np.median(
    mean_errors_plane2d
)

print(
    "\nMean-position baseline — mean 3D error:",
    baseline_mean_plane2d,
    "mm"
)

print(
    "Mean-position baseline — median 3D error:",
    baseline_median_plane2d,
    "mm"
)

improvement_plane2d = (
    (baseline_mean_plane2d - mean_error_plane2d)
    / baseline_mean_plane2d
    * 100
)

print(
    f"\n2D plane MLP mean 3D error: "
    f"{mean_error_plane2d:.3f} mm"
)

print(
    f"Baseline mean 3D error: "
    f"{baseline_mean_plane2d:.3f} mm"
)

print(
    f"Improvement over baseline: "
    f"{improvement_plane2d:.1f}%"
)
# Out:
# Mean annihilation position (train): [ 1.82516059  3.00046503 -8.14236138]
#
# Mean-position baseline — mean 3D error: 3.5481860379629215 mm
# Mean-position baseline — median 3D error: 3.6685539241921443 mm
#
# 2D plane MLP mean 3D error: 1.344 mm
# Baseline mean 3D error: 3.548 mm
# Improvement over baseline: 62.1%

# %%
overall_mae_plane2d = np.mean(absolute_errors_plane2d)
r2_overall_plane2d = r2_score(y_test_plane2d, xyz_pred_plane2d)

results_plane2d = {
    "model": "plane_2d",
    "mae_x": x_mae_plane2d,
    "mae_y": y_mae_plane2d,
    "mae_z": z_mae_plane2d,
    "mae_overall": overall_mae_plane2d,
    "mean_3d_error_mm": mean_error_plane2d,
    "median_3d_error_mm": median_error_plane2d,
    "r2_overall": r2_overall_plane2d,
    "improvement_over_mean_baseline_pct": improvement_plane2d,
}

# %% [markdown]
# **What changed vs. the original `plane_constrained_mlp.ipynb`:**
# - Data loading and event selection moved to the shared Section 0 (identical logic to what this notebook already had, now de-duplicated against `kerasMLP`).
# - Renamed `baseline_model` → `pcmlp_baseline` and `plane_model` → `pc_mlp`, and suffixed the rest of this section's variables with `_pcmlp`, so this section can coexist with Section 1 in the same notebook.
# - Otherwise this notebook was already clean and well-structured (it already used numbered markdown headers and shared helper functions) — the main change was renumbering to `2.x` and folding it in alongside `mlp`.

# %% [markdown]
# ---
# ## 4. Comparing `mlp`,  `pc_mlp` and `plane_2d`

# %% [markdown]
# 4.1 comparison rows

# %%
comparison_rows = [
    {
        "Model": "mlp",
        "MAE X (mm)": results_mlp["mae_x"],
        "MAE Y (mm)": results_mlp["mae_y"],
        "MAE Z (mm)": results_mlp["mae_z"],
        "Overall MAE (mm)": results_mlp["mae_overall"],
        "Mean 3D error (mm)": results_mlp["mean_3d_error_mm"],
        "Median 3D error (mm)": results_mlp["median_3d_error_mm"],
        "R2": results_mlp["r2_overall"],
    },
    {
        "Model": "pc_mlp",
        "MAE X (mm)": results_pcmlp["mae_x"],
        "MAE Y (mm)": results_pcmlp["mae_y"],
        "MAE Z (mm)": results_pcmlp["mae_z"],
        "Overall MAE (mm)": results_pcmlp["mae_overall"],
        "Mean 3D error (mm)": results_pcmlp["mean_3d_error_mm"],
        "Median 3D error (mm)": results_pcmlp["median_3d_error_mm"],
        "R2": results_pcmlp["r2_overall"],
    },

    {
        "Model": "plane_2d",
        "MAE X (mm)": results_plane2d["mae_x"],
        "MAE Y (mm)": results_plane2d["mae_y"],
        "MAE Z (mm)": results_plane2d["mae_z"],
        "Overall MAE (mm)": results_plane2d["mae_overall"],
        "Mean 3D error (mm)": results_plane2d["mean_3d_error_mm"],
        "Median 3D error (mm)": results_plane2d["median_3d_error_mm"],
        "R2": results_plane2d["r2_overall"],
    },
]

comparison_df = pd.DataFrame(comparison_rows).set_index("Model")
comparison_df
# Out:
#           MAE X (mm)  MAE Y (mm)  MAE Z (mm)  Overall MAE (mm)  \
# Model
# mlp         0.812047    0.863987    0.763769          0.813268
# pc_mlp      0.874075    0.877236    0.844257          0.865189
# plane_2d    0.691501    0.673207    0.659477          0.674728
#
#           Mean 3D error (mm)  Median 3D error (mm)        R2
# Model
# mlp                 1.620674              1.421563  0.731076
# pc_mlp              1.745533              1.570320  0.692255
# plane_2d            1.344227              1.060713  0.777255

# %% [markdown]
# 4.2 MAE and mean error per model

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 5))

models = comparison_df.index.tolist()

axes[0].bar(models, comparison_df["Overall MAE (mm)"], color=['blue', 'red', 'green'])
axes[0].set_ylabel("Overall MAE (mm)")
axes[0].set_title("Overall MAE by Model")
axes[0].grid(axis="y")

axes[1].bar(models, comparison_df["Mean 3D error (mm)"], color=['blue', 'red', 'green'])
axes[1].set_ylabel("Mean 3D reconstruction error (mm)")
axes[1].set_title("Mean 3D Error by Model")
axes[1].grid(axis="y")


plt.tight_layout()
plt.show()

# %%
axis_labels = ["X", "Y", "Z"]

mae_mlp_axes = [
    results_mlp["mae_x"],
    results_mlp["mae_y"],
    results_mlp["mae_z"]
]

mae_pcmlp_axes = [
    results_pcmlp["mae_x"],
    results_pcmlp["mae_y"],
    results_pcmlp["mae_z"]
]

mae_plane2d_axes = [
    results_plane2d["mae_x"],
    results_plane2d["mae_y"],
    results_plane2d["mae_z"]
]

x_pos = np.arange(len(axis_labels))

width = 0.25

plt.figure(figsize=(12, 8))

plt.bar(
    x_pos - width,
    mae_mlp_axes,
    width,
    label="MLP",
    color="blue"
)

plt.bar(
    x_pos,
    mae_pcmlp_axes,
    width,
    label="PC-MLP",
    color="red"
)

plt.bar(
    x_pos + width,
    mae_plane2d_axes,
    width,
    label="Plane 2D",
    color="green"
)

plt.xticks(
    x_pos,
    axis_labels
)

plt.ylabel("MAE (mm)")
plt.title("Per-Axis MAE: MLP vs PC-MLP vs Plane 2D")

plt.legend()

plt.grid(
    axis="y",
    alpha=0.3
)

plt.tight_layout()
plt.show()

# %% [markdown]
# 4.3 distrbution of 3d recosntuction errors

# %%
plt.figure(figsize=(10, 6))

plt.hist(
    errors_mlp,
    bins=30,
    alpha=0.5,
    label="MLP"
)

plt.hist(
    reconstruction_error_pc_mlp,
    bins=30,
    alpha=0.5,
    label="PC-MLP"
)

plt.hist(
    error_3d_plane2d,
    bins=30,
    alpha=0.5,
    label="Plane 2D"
)

plt.xlabel("3D reconstruction error (mm)")
plt.ylabel("Number of events")
plt.title("3D Reconstruction Error Distribution")

plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
for coordinate, index in [
    ("X", 0),
    ("Y", 1),
    ("Z", 2)
]:

    plt.figure(figsize=(8, 7))

    plt.scatter(
        y_test_mlp[:, index],
        y_pred_mlp[:, index],
        alpha=0.3,
        label="MLP"
    )

    plt.scatter(
        y_test_pcmlp[:, index],
        y_pred_pc_mlp[:, index],
        alpha=0.3,
        label="PC-MLP"
    )

    plt.scatter(
        y_test_plane2d[:, index],
        xyz_pred_plane2d[:, index],
        alpha=0.3,
        label="Plane 2D"
    )

    minimum = min(
        y_test_mlp[:, index].min(),
        y_test_pcmlp[:, index].min(),
        y_test_plane2d[:, index].min()
    )

    maximum = max(
        y_test_mlp[:, index].max(),
        y_test_pcmlp[:, index].max(),
        y_test_plane2d[:, index].max()
    )

    plt.plot(
        [minimum, maximum],
        [minimum, maximum],
        linestyle="--",
        label="Perfect prediction"
    )

    plt.xlabel(f"True {coordinate} (mm)")
    plt.ylabel(f"Predicted {coordinate} (mm)")

    plt.title(
        f"True vs Predicted {coordinate}"
    )

    plt.legend()
    plt.grid(alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
from sklearn.metrics import r2_score

for coordinate, index in [
    ("X", 0),
    ("Y", 1),
    ("Z", 2)
]:

    plt.figure(figsize=(9, 8))

    true_mlp = y_test_mlp[:, index]
    pred_mlp = y_pred_mlp[:, index]

    true_pcmlp = y_test_pcmlp[:, index]
    pred_pcmlp = y_pred_pc_mlp[:, index]

    true_plane2d = y_test_plane2d[:, index]
    pred_plane2d = xyz_pred_plane2d[:, index]

    plt.scatter(
        true_mlp,
        pred_mlp,
        alpha=0.3,
        label="MLP"
    )

    plt.scatter(
        true_pcmlp,
        pred_pcmlp,
        alpha=0.3,
        label="PC-MLP"
    )

    plt.scatter(
        true_plane2d,
        pred_plane2d,
        alpha=0.3,
        label="Plane 2D"
    )

    minimum = min(
        true_mlp.min(),
        pred_mlp.min(),
        true_pcmlp.min(),
        pred_pcmlp.min(),
        true_plane2d.min(),
        pred_plane2d.min()
    )

    maximum = max(
        true_mlp.max(),
        pred_mlp.max(),
        true_pcmlp.max(),
        pred_pcmlp.max(),
        true_plane2d.max(),
        pred_plane2d.max()
    )

    plt.plot(
        [minimum, maximum],
        [minimum, maximum],
        linestyle="--",
        linewidth=2,
        label="Perfect prediction: y = x"
    )

    mae_mlp = np.mean(
        np.abs(pred_mlp - true_mlp)
    )

    mae_pcmlp = np.mean(
        np.abs(pred_pcmlp - true_pcmlp)
    )

    mae_plane2d = np.mean(
        np.abs(pred_plane2d - true_plane2d)
    )

    r2_mlp = r2_score(
        true_mlp,
        pred_mlp
    )

    r2_pcmlp = r2_score(
        true_pcmlp,
        pred_pcmlp
    )

    r2_plane2d = r2_score(
        true_plane2d,
        pred_plane2d
    )

    metrics_text = (
        f"MLP:       MAE = {mae_mlp:.3f} mm,  R² = {r2_mlp:.3f}\n"
        f"PC-MLP:    MAE = {mae_pcmlp:.3f} mm,  R² = {r2_pcmlp:.3f}\n"
        f"Plane 2D:  MAE = {mae_plane2d:.3f} mm,  R² = {r2_plane2d:.3f}"
    )

    plt.text(
        0.05,
        0.05,
        metrics_text,
        transform=plt.gca().transAxes,
        verticalalignment="bottom",
        bbox=dict(
            boxstyle="round",
            alpha=0.85
        )
    )

    plt.xlabel(
        f"True {coordinate} (mm)"
    )

    plt.ylabel(
        f"Predicted {coordinate} (mm)"
    )

    plt.title(
        f"True vs Predicted {coordinate}: Model Comparison"
    )

    plt.legend()
    plt.grid(alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(9, 6))

plt.boxplot(
    [
        errors_mlp,
        reconstruction_error_pc_mlp,
        error_3d_plane2d
    ],
    labels=[
        "MLP",
        "PC-MLP",
        "Plane 2D"
    ]
)

plt.ylabel("3D reconstruction error (mm)")
plt.title("Distribution of 3D Reconstruction Errors")

plt.grid(
    axis="y",
    alpha=0.3
)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_6277/183301556.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
