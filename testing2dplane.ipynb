# %% [markdown]
# <a href="https://colab.research.google.com/github/mw2304/SummerProject2026/blob/main/testing2dplane.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install uproot
# %pip install awkward_pandas
# Out:
# Requirement already satisfied: uproot in /usr/local/lib/python3.13/dist-packages (5.7.6)
# Requirement already satisfied: awkward>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from uproot) (2.13.0)
# Requirement already satisfied: cramjam>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from uproot) (2.12.1)
# Requirement already satisfied: fsspec!=2026.2.0 in /usr/local/lib/python3.13/dist-packages (from uproot) (2025.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from uproot) (2.1.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from uproot) (26.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.13/dist-packages (from uproot) (4.0.1)
# Requirement already satisfied: awkward-cpp==56 in /usr/local/lib/python3.13/dist-packages (from awkward>=2.8.2->uproot) (56)
# Requirement already satisfied: awkward_pandas in /usr/local/lib/python3.13/dist-packages (2023.8.0)
# Requirement already satisfied: awkward>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from awkward_pandas) (2.13.0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.13/dist-packages (from awkward_pandas) (2.2.3)
# Requirement already satisfied: awkward-cpp==56 in /usr/local/lib/python3.13/dist-packages (from awkward>=2.0.0->awkward_pandas) (56)
# Requirement already satisfied: fsspec>=2022.11.0 in /usr/local/lib/python3.13/dist-packages (from awkward>=2.0.0->awkward_pandas) (2025.3.0)
# Requirement already satisfied: numpy>=1.21.3 in /usr/local/lib/python3.13/dist-packages (from awkward>=2.0.0->awkward_pandas) (2.1.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from awkward>=2.0.0->awkward_pandas) (26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.2->awkward_pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.2->awkward_pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.2->awkward_pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2->awkward_pandas) (1.17.0)

# %%
import numpy as np
import pandas as pd
import uproot
import os

import matplotlib.pyplot as plt

import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score

RANDOM_STATE = 42

print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.20.0

# %%
ROOT_FILE = "augmerged.root"

file = uproot.open(ROOT_FILE)
print(file.keys())

tree = file["ThreeG_NCS"]
print(tree.keys())

branches = [
    "RunID", "EventID",
    "GammaIndex", "NGammas",
    "X_mm", "Y_mm", "Z_mm",
    "EnergyDeposit_keV", "PreEnergy_keV", "PostEnergy_keV",
    "AnnihilX_mm", "AnnihilY_mm", "AnnihilZ_mm",
]

df = tree.arrays(branches, library="pd")
df.head()
# Out:
# ['TwoG_NCS;1', 'TwoG_PhantomSCS;1', 'TwoG_ScannerSCS;1', 'TwoG_PhantomSCS_ScannerSCS;1', 'TwoG_PhantomDCS;1', 'TwoG_ScannerDCS;1', 'TwoG_PhantomSCS_ScannerDCS;1', 'TwoG_PhantomDCS_ScannerSCS;1', 'TwoG_PhantomDCS_ScannerDCS;1', 'TwoG_MCS;1', 'TwoG_Excluded;1', 'ThreeG_NCS;1', 'ThreeG_ScannerSCS;1', 'ThreeG_ScannerDCS;1', 'ThreeG_ScannerTCS;1', 'ThreeG_MCS;1', 'ThreeG_Excluded;1', 'Run;1']
# ['RunID', 'EventID', 'NGammas', 'AnnihilX_mm', 'AnnihilY_mm', 'AnnihilZ_mm', 'GammaIndex', 'GammaTrackID', 'GammaParentID', 'HitIndex', 'VolumeID', 'VolumeName', 'ProcessID', 'ProcessName', 'EnergyDeposit_keV', 'PreEnergy_keV', 'PostEnergy_keV', 'X_mm', 'Y_mm', 'Z_mm', 'Theta_deg', 'Phi_deg', 'DeltaPhi01_deg', 'DeltaPhi02_deg', 'DeltaPhi12_deg']
#               RunID  EventID  GammaIndex  NGammas       X_mm       Y_mm  \
# 0  slurm_36283167_1       43           0        3  22.533781  45.725643
# 1  slurm_36283167_1       43           1        3 -19.154974 -41.295967
# 2  slurm_36283167_1       43           2        3  10.009033  22.802109
# 3  slurm_36283167_1       56           0        3  15.187184  14.526692
# 4  slurm_36283167_1       56           1        3   1.183054 -10.753192
#
#         Z_mm  EnergyDeposit_keV  PreEnergy_keV  PostEnergy_keV  AnnihilX_mm  \
# 0  -6.039716         187.380234     187.380234             0.0     3.079860
# 1  42.954437         471.598907     471.598907             0.0     3.079860
# 2 -44.240387         363.018677     363.018677             0.0     3.079860
# 3  46.622974         492.708618     492.708618             0.0    -0.369778
# 4 -51.622868         304.623718     304.623718             0.0    -0.369778
#
#    AnnihilY_mm  AnnihilZ_mm
# 0     6.565360    -6.969770
# 1     6.565360    -6.969770
# 2     6.565360    -6.969770
# 3     0.324251    -4.727468
# 4     0.324251    -4.727468

# %%
N_EVENTS = 15000

events = df[["RunID", "EventID"]].drop_duplicates()
events_subset = events.head(N_EVENTS)

df_subset = df.merge(events_subset, on=["RunID", "EventID"], how="inner")

print("Events selected:", len(events_subset))
print("Rows selected:  ", len(df_subset))
print("Events in subset:", df_subset.groupby(["RunID", "EventID"]).ngroups)
# Out:
# Events selected: 15000
# Rows selected:   45000
# Events in subset: 15000

# %%
#ignore
def build_event_arrays_2d(df_events):

    features_list = []
    targets_list = []
    plane_list = []

    for (run_id, event_id), event in df_events.groupby(
        ["RunID", "EventID"]
    ):

        event = event.sort_values("GammaIndex")

        if len(event) < 3:
            continue

        event = event.iloc[:3]

        hit1 = event[
            ["X_mm", "Y_mm", "Z_mm"]
        ].iloc[0].values.astype(float)

        hit2 = event[
            ["X_mm", "Y_mm", "Z_mm"]
        ].iloc[1].values.astype(float)

        hit3 = event[
            ["X_mm", "Y_mm", "Z_mm"]
        ].iloc[2].values.astype(float)

        v1 = hit2 - hit1
        v2 = hit3 - hit1

        normal = np.cross(v1, v2)
        normal_length = np.linalg.norm(normal)

        if normal_length < 1e-8:
            continue

        normal = normal / normal_length

        basis_u = v1 / (
            np.linalg.norm(v1) + 1e-8
        )

        basis_v = np.cross(normal, basis_u)

        basis_v = basis_v / (
            np.linalg.norm(basis_v) + 1e-8
        )

        plane_data = np.concatenate([
            hit1,
            normal,
            basis_u,
            basis_v
        ])

        plane_list.append(plane_data)

        energy1 = float(
            event.iloc[0]["EnergyDeposit_keV"]
        )

        energy2 = float(
            event.iloc[1]["EnergyDeposit_keV"]
        )

        energy3 = float(
            event.iloc[2]["EnergyDeposit_keV"]
        )

        d12 = np.linalg.norm(hit1 - hit2)
        d13 = np.linalg.norm(hit1 - hit3)
        d23 = np.linalg.norm(hit2 - hit3)

        def angle_at(vertex, a, b):

            va = a - vertex
            vb = b - vertex

            cos_angle = np.dot(va, vb) / (
                np.linalg.norm(va)
                * np.linalg.norm(vb)
                + 1e-8
            )

            return np.arccos(
                np.clip(cos_angle, -1.0, 1.0)
            )

        angle1 = angle_at(hit1, hit2, hit3)
        angle2 = angle_at(hit2, hit1, hit3)
        angle3 = angle_at(hit3, hit1, hit2)

        features = np.concatenate([
            hit1, [energy1],
            hit2, [energy2],
            hit3, [energy3],
            [d12, d13, d23],
            [angle1, angle2, angle3]
        ])

        features_list.append(features)

        target = event[
            [
                "AnnihilX_mm",
                "AnnihilY_mm",
                "AnnihilZ_mm"
            ]
        ].iloc[0].values.astype(float)

        targets_list.append(target)

    return (
        np.array(features_list),
        np.array(targets_list),
        np.array(plane_list)
    )


X_plane2d, y_plane2d, plane_data_plane2d = build_event_arrays_2d(
    df_subset
)

print("X_plane2d shape:", X_plane2d.shape)
print("y_plane2d shape:", y_plane2d.shape)
print("plane_data_plane2d shape:", plane_data_plane2d.shape)
# Out:
# X_plane2d shape: (15000, 18)
# y_plane2d shape: (15000, 3)
# plane_data_plane2d shape: (15000, 12)

# %%
#new equation
def build_event_arrays_2d(df_events):

    features_list = []
    targets_list = []
    plane_list = []

    for (run_id, event_id), event in df_events.groupby(
        ["RunID", "EventID"]
    ):

        # Order hits by decreasing energy, not GammaIndex — GammaIndex is a
        # Geant4 bookkeeping label with no physical meaning.
        event = event.sort_values(
            ["EnergyDeposit_keV", "GammaIndex"],
            ascending=[False, True]
        ).reset_index(drop=True)

        if len(event) < 3:
            continue

        event = event.iloc[:3]

        hit1 = event[
            ["X_mm", "Y_mm", "Z_mm"]
        ].iloc[0].values.astype(float)

        hit2 = event[
            ["X_mm", "Y_mm", "Z_mm"]
        ].iloc[1].values.astype(float)

        hit3 = event[
            ["X_mm", "Y_mm", "Z_mm"]
        ].iloc[2].values.astype(float)

        v1 = hit2 - hit1
        v2 = hit3 - hit1

        normal = np.cross(v1, v2)
        normal_length = np.linalg.norm(normal)

        if normal_length < 1e-8:
            continue

        normal = normal / normal_length

        basis_u = v1 / (
            np.linalg.norm(v1) + 1e-8
        )

        basis_v = np.cross(normal, basis_u)

        basis_v = basis_v / (
            np.linalg.norm(basis_v) + 1e-8
        )

        plane_data = np.concatenate([
            hit1,
            normal,
            basis_u,
            basis_v
        ])

        plane_list.append(plane_data)

        energy1 = float(
            event.iloc[0]["EnergyDeposit_keV"]
        )

        energy2 = float(
            event.iloc[1]["EnergyDeposit_keV"]
        )

        energy3 = float(
            event.iloc[2]["EnergyDeposit_keV"]
        )

        d12 = np.linalg.norm(hit1 - hit2)
        d13 = np.linalg.norm(hit1 - hit3)
        d23 = np.linalg.norm(hit2 - hit3)

        def gamma_opening_angle(e_i, e_j, e_k):
            # Physical emission angle between photons i and j, from
            # energy/momentum conservation (Fujimoto et al. 2026, Eq. 4):
            # https://doi.org/10.1038/s42005-026-02782-6
            cos_theta = (-e_i**2 - e_j**2 + e_k**2) / (2 * e_i * e_j + 1e-8)
            return np.arccos(np.clip(cos_theta, -1.0, 1.0))

        angle1 = gamma_opening_angle(energy1, energy2, energy3)  # θ between γ1, γ2
        angle2 = gamma_opening_angle(energy2, energy3, energy1)  # θ between γ2, γ3
        angle3 = gamma_opening_angle(energy3, energy1, energy2)  # θ between γ3, γ1

        features = np.concatenate([
            hit1, [energy1],
            hit2, [energy2],
            hit3, [energy3],
            [d12, d13, d23],
            [angle1, angle2, angle3]
        ])

        features_list.append(features)

        target = event[
            [
                "AnnihilX_mm",
                "AnnihilY_mm",
                "AnnihilZ_mm"
            ]
        ].iloc[0].values.astype(float)

        targets_list.append(target)

    return (
        np.array(features_list),
        np.array(targets_list),
        np.array(plane_list)
    )


X_plane2d, y_plane2d, plane_data_plane2d = build_event_arrays_2d(
    df_subset
)

print("X_plane2d shape:", X_plane2d.shape)
print("y_plane2d shape:", y_plane2d.shape)
print("plane_data_plane2d shape:", plane_data_plane2d.shape)
# Out:
# X_plane2d shape: (15000, 18)
# y_plane2d shape: (15000, 3)
# plane_data_plane2d shape: (15000, 12)

# %%
X_train_plane2d, X_temp_plane2d, \
y_train_plane2d, y_temp_plane2d, \
plane_train_plane2d, plane_temp_plane2d = train_test_split(
    X_plane2d,
    y_plane2d,
    plane_data_plane2d,
    test_size=0.20,
    random_state=RANDOM_STATE
)

X_val_plane2d, X_test_plane2d, \
y_val_plane2d, y_test_plane2d, \
plane_val_plane2d, plane_test_plane2d = train_test_split(
    X_temp_plane2d,
    y_temp_plane2d,
    plane_temp_plane2d,
    test_size=0.33,
    random_state=RANDOM_STATE
)

print("Training:", X_train_plane2d.shape)
print("Validation:", X_val_plane2d.shape)
print("Test:", X_test_plane2d.shape)
# Out:
# Training: (12000, 18)
# Validation: (2010, 18)
# Test: (990, 18)

# %%
input_scaler_plane2d = StandardScaler()

X_train_scaled_plane2d = input_scaler_plane2d.fit_transform(
    X_train_plane2d
)

X_val_scaled_plane2d = input_scaler_plane2d.transform(
    X_val_plane2d
)

X_test_scaled_plane2d = input_scaler_plane2d.transform(
    X_test_plane2d
)

# %%
def xyz_to_uv_plane2d(y_xyz, plane_data):

    plane_point = plane_data[:, 0:3]
    basis_u = plane_data[:, 6:9]
    basis_v = plane_data[:, 9:12]

    displacement = y_xyz - plane_point

    u = np.sum(
        displacement * basis_u,
        axis=1
    )

    v = np.sum(
        displacement * basis_v,
        axis=1
    )

    return np.column_stack([u, v])


y_train_uv_plane2d = xyz_to_uv_plane2d(
    y_train_plane2d,
    plane_train_plane2d
)

y_val_uv_plane2d = xyz_to_uv_plane2d(
    y_val_plane2d,
    plane_val_plane2d
)

y_test_uv_plane2d = xyz_to_uv_plane2d(
    y_test_plane2d,
    plane_test_plane2d
)

print("Training UV:", y_train_uv_plane2d.shape)
print("Validation UV:", y_val_uv_plane2d.shape)
print("Test UV:", y_test_uv_plane2d.shape)
# Out:
# Training UV: (12000, 2)
# Validation UV: (2010, 2)
# Test UV: (990, 2)

# %%
class Plane2DMLP(tf.keras.Model):

    def __init__(self, hidden_units=100):
        super().__init__()

        self.dense1 = tf.keras.layers.Dense(
            hidden_units,
            activation="relu"
        )

        self.dense2 = tf.keras.layers.Dense(
            hidden_units,
            activation="relu"
        )

        self.dense3 = tf.keras.layers.Dense(
            hidden_units,
            activation="relu" #extra dense layer
        )

        self.output_layer = tf.keras.layers.Dense(2)

    def call(self, x, training=False):

        x = self.dense1(x)
        x = self.dense2(x)
        x = self.dense3(x)

        return self.output_layer(x)

# %%
model_plane2d = Plane2DMLP(
    hidden_units=100
)

model_plane2d.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=0.001
    ),
    loss="mae",
    metrics=["mae"]
)

# %%
history_plane2d = model_plane2d.fit(
    X_train_scaled_plane2d,
    y_train_uv_plane2d,
    validation_data=(
        X_val_scaled_plane2d,
        y_val_uv_plane2d
    ),
    epochs=200,
    batch_size=32,
    shuffle=True
)
# Out:
# Epoch 1/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 5.8124 - mae: 5.8124 - val_loss: 1.3804 - val_mae: 1.3804
# Epoch 2/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.0240 - mae: 1.0240 - val_loss: 0.9489 - val_mae: 0.9489
# Epoch 3/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8222 - mae: 0.8222 - val_loss: 0.9447 - val_mae: 0.9447
# Epoch 4/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.7442 - mae: 0.7442 - val_loss: 0.7252 - val_mae: 0.7252
# Epoch 5/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6795 - mae: 0.6795 - val_loss: 0.6619 - val_mae: 0.6619
# Epoch 6/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6239 - mae: 0.6239 - val_loss: 0.7034 - val_mae: 0.7034
# Epoch 7/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6174 - mae: 0.6174 - val_loss: 0.5361 - val_mae: 0.5361
# Epoch 8/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5873 - mae: 0.5873 - val_loss: 0.6203 - val_mae: 0.6203
# Epoch 9/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5679 - mae: 0.5679 - val_loss: 0.6409 - val_mae: 0.6409
# Epoch 10/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5546 - mae: 0.5546 - val_loss: 0.5313 - val_mae: 0.5313
# Epoch 11/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5276 - mae: 0.5276 - val_loss: 0.5052 - val_mae: 0.5052
# Epoch 12/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.5322 - mae: 0.5322 - val_loss: 0.6535 - val_mae: 0.6535
# Epoch 13/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5139 - mae: 0.5139 - val_loss: 0.5842 - val_mae: 0.5842
# Epoch 14/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4927 - mae: 0.4927 - val_loss: 0.5446 - val_mae: 0.5446
# Epoch 15/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4834 - mae: 0.4834 - val_loss: 0.5083 - val_mae: 0.5083
# Epoch 16/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4777 - mae: 0.4777 - val_loss: 0.4445 - val_mae: 0.4445
# Epoch 17/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4754 - mae: 0.4754 - val_loss: 0.4808 - val_mae: 0.4808
# Epoch 18/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4615 - mae: 0.4615 - val_loss: 0.5042 - val_mae: 0.5042
# Epoch 19/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4510 - mae: 0.4510 - val_loss: 0.4372 - val_mae: 0.4372
# Epoch 20/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4729 - mae: 0.4729 - val_loss: 0.4458 - val_mae: 0.4458
# Epoch 21/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4487 - mae: 0.4487 - val_loss: 0.4135 - val_mae: 0.4135
# Epoch 22/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4424 - mae: 0.4424 - val_loss: 0.4370 - val_mae: 0.4370
# Epoch 23/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4265 - mae: 0.4265 - val_loss: 0.4687 - val_mae: 0.4687
# Epoch 24/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4090 - mae: 0.4090 - val_loss: 0.5055 - val_mae: 0.5055
# Epoch 25/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4328 - mae: 0.4328 - val_loss: 0.4305 - val_mae: 0.4305
# Epoch 26/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4128 - mae: 0.4128 - val_loss: 0.4732 - val_mae: 0.4732
# Epoch 27/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4163 - mae: 0.4163 - val_loss: 0.3987 - val_mae: 0.3987
# Epoch 28/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4025 - mae: 0.4025 - val_loss: 0.3775 - val_mae: 0.3775
# Epoch 29/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4019 - mae: 0.4019 - val_loss: 0.3884 - val_mae: 0.3884
# Epoch 30/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3956 - mae: 0.3956 - val_loss: 0.4641 - val_mae: 0.4641
# Epoch 31/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3953 - mae: 0.3953 - val_loss: 0.4060 - val_mae: 0.4060
# Epoch 32/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3788 - mae: 0.3788 - val_loss: 0.3518 - val_mae: 0.3518
# Epoch 33/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.3811 - mae: 0.3811 - val_loss: 0.3834 - val_mae: 0.3834
# Epoch 34/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3803 - mae: 0.3803 - val_loss: 0.3911 - val_mae: 0.3911
# Epoch 35/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3718 - mae: 0.3718 - val_loss: 0.4045 - val_mae: 0.4045
# Epoch 36/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3742 - mae: 0.3742 - val_loss: 0.4982 - val_mae: 0.4982
# Epoch 37/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3764 - mae: 0.3764 - val_loss: 0.4029 - val_mae: 0.4029
# Epoch 38/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3655 - mae: 0.3655 - val_loss: 0.4504 - val_mae: 0.4504
# Epoch 39/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3695 - mae: 0.3695 - val_loss: 0.3521 - val_mae: 0.3521
# Epoch 40/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3594 - mae: 0.3594 - val_loss: 0.4447 - val_mae: 0.4447
# Epoch 41/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3686 - mae: 0.3686 - val_loss: 0.3835 - val_mae: 0.3835
# Epoch 42/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3557 - mae: 0.3557 - val_loss: 0.4020 - val_mae: 0.4020
# Epoch 43/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3409 - mae: 0.3409 - val_loss: 0.3721 - val_mae: 0.3721
# Epoch 44/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.3404 - mae: 0.3404 - val_loss: 0.3579 - val_mae: 0.3579
# Epoch 45/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3457 - mae: 0.3457 - val_loss: 0.3807 - val_mae: 0.3807
# Epoch 46/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3599 - mae: 0.3599 - val_loss: 0.3475 - val_mae: 0.3475
# Epoch 47/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3275 - mae: 0.3275 - val_loss: 0.3293 - val_mae: 0.3293
# Epoch 48/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3471 - mae: 0.3471 - val_loss: 0.3303 - val_mae: 0.3303
# Epoch 49/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3287 - mae: 0.3287 - val_loss: 0.3106 - val_mae: 0.3106
# Epoch 50/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3318 - mae: 0.3318 - val_loss: 0.3369 - val_mae: 0.3369
# Epoch 51/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3233 - mae: 0.3233 - val_loss: 0.4097 - val_mae: 0.4097
# Epoch 52/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3309 - mae: 0.3309 - val_loss: 0.3659 - val_mae: 0.3659
# Epoch 53/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3244 - mae: 0.3244 - val_loss: 0.3160 - val_mae: 0.3160
# Epoch 54/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3200 - mae: 0.3200 - val_loss: 0.3052 - val_mae: 0.3052
# Epoch 55/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3257 - mae: 0.3257 - val_loss: 0.3332 - val_mae: 0.3332
# Epoch 56/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3310 - mae: 0.3310 - val_loss: 0.3739 - val_mae: 0.3739
# Epoch 57/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3136 - mae: 0.3136 - val_loss: 0.2965 - val_mae: 0.2965
# Epoch 58/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3304 - mae: 0.3304 - val_loss: 0.3209 - val_mae: 0.3209
# Epoch 59/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3088 - mae: 0.3088 - val_loss: 0.3210 - val_mae: 0.3210
# Epoch 60/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3082 - mae: 0.3082 - val_loss: 0.2931 - val_mae: 0.2931
# Epoch 61/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3084 - mae: 0.3084 - val_loss: 0.2837 - val_mae: 0.2837
# Epoch 62/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3205 - mae: 0.3205 - val_loss: 0.3201 - val_mae: 0.3201
# Epoch 63/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2959 - mae: 0.2959 - val_loss: 0.3391 - val_mae: 0.3391
# Epoch 64/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3136 - mae: 0.3136 - val_loss: 0.3227 - val_mae: 0.3227
# Epoch 65/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2931 - mae: 0.2931 - val_loss: 0.4713 - val_mae: 0.4713
# Epoch 66/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2979 - mae: 0.2979 - val_loss: 0.3414 - val_mae: 0.3414
# Epoch 67/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2980 - mae: 0.2980 - val_loss: 0.3287 - val_mae: 0.3287
# Epoch 68/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2972 - mae: 0.2972 - val_loss: 0.3338 - val_mae: 0.3338
# Epoch 69/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3113 - mae: 0.3113 - val_loss: 0.3475 - val_mae: 0.3475
# Epoch 70/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3105 - mae: 0.3105 - val_loss: 0.3393 - val_mae: 0.3393
# Epoch 71/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2908 - mae: 0.2908 - val_loss: 0.3127 - val_mae: 0.3127
# Epoch 72/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.2860 - mae: 0.2860 - val_loss: 0.2958 - val_mae: 0.2958
# Epoch 73/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2847 - mae: 0.2847 - val_loss: 0.2694 - val_mae: 0.2694
# Epoch 74/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2950 - mae: 0.2950 - val_loss: 0.2962 - val_mae: 0.2962
# Epoch 75/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2806 - mae: 0.2806 - val_loss: 0.2915 - val_mae: 0.2915
# Epoch 76/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2945 - mae: 0.2945 - val_loss: 0.2850 - val_mae: 0.2850
# Epoch 77/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3044 - mae: 0.3044 - val_loss: 0.2808 - val_mae: 0.2808
# Epoch 78/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2816 - mae: 0.2816 - val_loss: 0.3561 - val_mae: 0.3561
# Epoch 79/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3031 - mae: 0.3031 - val_loss: 0.3194 - val_mae: 0.3194
# Epoch 80/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2831 - mae: 0.2831 - val_loss: 0.4033 - val_mae: 0.4033
# Epoch 81/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2838 - mae: 0.2838 - val_loss: 0.4014 - val_mae: 0.4014
# Epoch 82/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2818 - mae: 0.2818 - val_loss: 0.2583 - val_mae: 0.2583
# Epoch 83/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2807 - mae: 0.2807 - val_loss: 0.2893 - val_mae: 0.2893
# Epoch 84/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2680 - mae: 0.2680 - val_loss: 0.2788 - val_mae: 0.2788
# Epoch 85/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2780 - mae: 0.2780 - val_loss: 0.3001 - val_mae: 0.3001
# Epoch 86/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2784 - mae: 0.2784 - val_loss: 0.3315 - val_mae: 0.3315
# Epoch 87/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2666 - mae: 0.2666 - val_loss: 0.3056 - val_mae: 0.3056
# Epoch 88/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2728 - mae: 0.2728 - val_loss: 0.2880 - val_mae: 0.2880
# Epoch 89/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2789 - mae: 0.2789 - val_loss: 0.2736 - val_mae: 0.2736
# Epoch 90/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2672 - mae: 0.2672 - val_loss: 0.2583 - val_mae: 0.2583
# Epoch 91/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2734 - mae: 0.2734 - val_loss: 0.2949 - val_mae: 0.2949
# Epoch 92/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2652 - mae: 0.2652 - val_loss: 0.3558 - val_mae: 0.3558
# Epoch 93/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2778 - mae: 0.2778 - val_loss: 0.2757 - val_mae: 0.2757
# Epoch 94/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2594 - mae: 0.2594 - val_loss: 0.3059 - val_mae: 0.3059
# Epoch 95/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2547 - mae: 0.2547 - val_loss: 0.2380 - val_mae: 0.2380
# Epoch 96/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2602 - mae: 0.2602 - val_loss: 0.2308 - val_mae: 0.2308
# Epoch 97/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2604 - mae: 0.2604 - val_loss: 0.3070 - val_mae: 0.3070
# Epoch 98/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2546 - mae: 0.2546 - val_loss: 0.2606 - val_mae: 0.2606
# Epoch 99/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2784 - mae: 0.2784 - val_loss: 0.2513 - val_mae: 0.2513
# Epoch 100/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2599 - mae: 0.2599 - val_loss: 0.2671 - val_mae: 0.2671
# Epoch 101/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2564 - mae: 0.2564 - val_loss: 0.2954 - val_mae: 0.2954
# Epoch 102/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2502 - mae: 0.2502 - val_loss: 0.2642 - val_mae: 0.2642
# Epoch 103/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2607 - mae: 0.2607 - val_loss: 0.2247 - val_mae: 0.2247
# Epoch 104/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2469 - mae: 0.2469 - val_loss: 0.2547 - val_mae: 0.2547
# Epoch 105/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2610 - mae: 0.2610 - val_loss: 0.2467 - val_mae: 0.2467
# Epoch 106/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2712 - mae: 0.2712 - val_loss: 0.2328 - val_mae: 0.2328
# Epoch 107/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2695 - mae: 0.2695 - val_loss: 0.2389 - val_mae: 0.2389
# Epoch 108/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2588 - mae: 0.2588 - val_loss: 0.2385 - val_mae: 0.2385
# Epoch 109/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2481 - mae: 0.2481 - val_loss: 0.2475 - val_mae: 0.2475
# Epoch 110/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2410 - mae: 0.2410 - val_loss: 0.2492 - val_mae: 0.2492
# Epoch 111/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2520 - mae: 0.2520 - val_loss: 0.2440 - val_mae: 0.2440
# Epoch 112/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2436 - mae: 0.2436 - val_loss: 0.2186 - val_mae: 0.2186
# Epoch 113/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2484 - mae: 0.2484 - val_loss: 0.3032 - val_mae: 0.3032
# Epoch 114/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2429 - mae: 0.2429 - val_loss: 0.2282 - val_mae: 0.2282
# Epoch 115/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2576 - mae: 0.2576 - val_loss: 0.3084 - val_mae: 0.3084
# Epoch 116/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2365 - mae: 0.2365 - val_loss: 0.2223 - val_mae: 0.2223
# Epoch 117/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2372 - mae: 0.2372 - val_loss: 0.2712 - val_mae: 0.2712
# Epoch 118/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2451 - mae: 0.2451 - val_loss: 0.2363 - val_mae: 0.2363
# Epoch 119/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2492 - mae: 0.2492 - val_loss: 0.3370 - val_mae: 0.3370
# Epoch 120/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2457 - mae: 0.2457 - val_loss: 0.2270 - val_mae: 0.2270
# Epoch 121/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2381 - mae: 0.2381 - val_loss: 0.3112 - val_mae: 0.3112
# Epoch 122/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2371 - mae: 0.2371 - val_loss: 0.2272 - val_mae: 0.2272
# Epoch 123/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2359 - mae: 0.2359 - val_loss: 0.2642 - val_mae: 0.2642
# Epoch 124/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2309 - mae: 0.2309 - val_loss: 0.2323 - val_mae: 0.2323
# Epoch 125/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2434 - mae: 0.2434 - val_loss: 0.2552 - val_mae: 0.2552
# Epoch 126/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2373 - mae: 0.2373 - val_loss: 0.2965 - val_mae: 0.2965
# Epoch 127/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2326 - mae: 0.2326 - val_loss: 0.2302 - val_mae: 0.2302
# Epoch 128/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2351 - mae: 0.2351 - val_loss: 0.2191 - val_mae: 0.2191
# Epoch 129/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2264 - mae: 0.2264 - val_loss: 0.2474 - val_mae: 0.2474
# Epoch 130/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2291 - mae: 0.2291 - val_loss: 0.2026 - val_mae: 0.2026
# Epoch 131/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2406 - mae: 0.2406 - val_loss: 0.2801 - val_mae: 0.2801
# Epoch 132/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2384 - mae: 0.2384 - val_loss: 0.2985 - val_mae: 0.2985
# Epoch 133/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2367 - mae: 0.2367 - val_loss: 0.2278 - val_mae: 0.2278
# Epoch 134/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2313 - mae: 0.2313 - val_loss: 0.2532 - val_mae: 0.2532
# Epoch 135/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2180 - mae: 0.2180 - val_loss: 0.2433 - val_mae: 0.2433
# Epoch 136/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2241 - mae: 0.2241 - val_loss: 0.2444 - val_mae: 0.2444
# Epoch 137/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2329 - mae: 0.2329 - val_loss: 0.2212 - val_mae: 0.2212
# Epoch 138/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2224 - mae: 0.2224 - val_loss: 0.2531 - val_mae: 0.2531
# Epoch 139/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2370 - mae: 0.2370 - val_loss: 0.2603 - val_mae: 0.2603
# Epoch 140/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2424 - mae: 0.2424 - val_loss: 0.3110 - val_mae: 0.3110
# Epoch 141/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2266 - mae: 0.2266 - val_loss: 0.2419 - val_mae: 0.2419
# Epoch 142/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2249 - mae: 0.2249 - val_loss: 0.2492 - val_mae: 0.2492
# Epoch 143/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2294 - mae: 0.2294 - val_loss: 0.2434 - val_mae: 0.2434
# Epoch 144/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2281 - mae: 0.2281 - val_loss: 0.2206 - val_mae: 0.2206
# Epoch 145/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2195 - mae: 0.2195 - val_loss: 0.2130 - val_mae: 0.2130
# Epoch 146/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2308 - mae: 0.2308 - val_loss: 0.2723 - val_mae: 0.2723
# Epoch 147/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2291 - mae: 0.2291 - val_loss: 0.2474 - val_mae: 0.2474
# Epoch 148/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2142 - mae: 0.2142 - val_loss: 0.2766 - val_mae: 0.2766
# Epoch 149/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2202 - mae: 0.2202 - val_loss: 0.2767 - val_mae: 0.2767
# Epoch 150/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2286 - mae: 0.2286 - val_loss: 0.2201 - val_mae: 0.2201
# Epoch 151/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2170 - mae: 0.2170 - val_loss: 0.2271 - val_mae: 0.2271
# Epoch 152/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2118 - mae: 0.2118 - val_loss: 0.2305 - val_mae: 0.2305
# Epoch 153/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2239 - mae: 0.2239 - val_loss: 0.2180 - val_mae: 0.2180
# Epoch 154/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2153 - mae: 0.2153 - val_loss: 0.2475 - val_mae: 0.2475
# Epoch 155/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2131 - mae: 0.2131 - val_loss: 0.1933 - val_mae: 0.1933
# Epoch 156/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2468 - mae: 0.2468 - val_loss: 0.2032 - val_mae: 0.2032
# Epoch 157/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2174 - mae: 0.2174 - val_loss: 0.2354 - val_mae: 0.2354
# Epoch 158/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2257 - mae: 0.2257 - val_loss: 0.2104 - val_mae: 0.2104
# Epoch 159/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2131 - mae: 0.2131 - val_loss: 0.2488 - val_mae: 0.2488
# Epoch 160/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2067 - mae: 0.2067 - val_loss: 0.2241 - val_mae: 0.2241
# Epoch 161/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2269 - mae: 0.2269 - val_loss: 0.3033 - val_mae: 0.3033
# Epoch 162/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2205 - mae: 0.2205 - val_loss: 0.2200 - val_mae: 0.2200
# Epoch 163/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2066 - mae: 0.2066 - val_loss: 0.2041 - val_mae: 0.2041
# Epoch 164/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2161 - mae: 0.2161 - val_loss: 0.2589 - val_mae: 0.2589
# Epoch 165/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2159 - mae: 0.2159 - val_loss: 0.2268 - val_mae: 0.2268
# Epoch 166/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2173 - mae: 0.2173 - val_loss: 0.2389 - val_mae: 0.2389
# Epoch 167/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2135 - mae: 0.2135 - val_loss: 0.2091 - val_mae: 0.2091
# Epoch 168/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2093 - mae: 0.2093 - val_loss: 0.2191 - val_mae: 0.2191
# Epoch 169/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2095 - mae: 0.2095 - val_loss: 0.2496 - val_mae: 0.2496
# Epoch 170/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2023 - mae: 0.2023 - val_loss: 0.2131 - val_mae: 0.2131
# Epoch 171/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2168 - mae: 0.2168 - val_loss: 0.2214 - val_mae: 0.2214
# Epoch 172/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2128 - mae: 0.2128 - val_loss: 0.2108 - val_mae: 0.2108
# Epoch 173/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2130 - mae: 0.2130 - val_loss: 0.2092 - val_mae: 0.2092
# Epoch 174/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2091 - mae: 0.2091 - val_loss: 0.2951 - val_mae: 0.2951
# Epoch 175/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2092 - mae: 0.2092 - val_loss: 0.2832 - val_mae: 0.2832
# Epoch 176/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2103 - mae: 0.2103 - val_loss: 0.2405 - val_mae: 0.2405
# Epoch 177/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2178 - mae: 0.2178 - val_loss: 0.2411 - val_mae: 0.2411
# Epoch 178/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1997 - mae: 0.1997 - val_loss: 0.1886 - val_mae: 0.1886
# Epoch 179/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2052 - mae: 0.2052 - val_loss: 0.2319 - val_mae: 0.2319
# Epoch 180/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2045 - mae: 0.2045 - val_loss: 0.2175 - val_mae: 0.2175
# Epoch 181/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2111 - mae: 0.2111 - val_loss: 0.1945 - val_mae: 0.1945
# Epoch 182/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2170 - mae: 0.2170 - val_loss: 0.1887 - val_mae: 0.1887
# Epoch 183/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2038 - mae: 0.2038 - val_loss: 0.2249 - val_mae: 0.2249
# Epoch 184/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2053 - mae: 0.2053 - val_loss: 0.2763 - val_mae: 0.2763
# Epoch 185/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2027 - mae: 0.2027 - val_loss: 0.2127 - val_mae: 0.2127
# Epoch 186/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2108 - mae: 0.2108 - val_loss: 0.2834 - val_mae: 0.2834
# Epoch 187/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1988 - mae: 0.1988 - val_loss: 0.2748 - val_mae: 0.2748
# Epoch 188/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2142 - mae: 0.2142 - val_loss: 0.2551 - val_mae: 0.2551
# Epoch 189/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2167 - mae: 0.2167 - val_loss: 0.2143 - val_mae: 0.2143
# Epoch 190/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1988 - mae: 0.1988 - val_loss: 0.1895 - val_mae: 0.1895
# Epoch 191/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2036 - mae: 0.2036 - val_loss: 0.1895 - val_mae: 0.1895
# Epoch 192/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1961 - mae: 0.1961 - val_loss: 0.1949 - val_mae: 0.1949
# Epoch 193/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2080 - mae: 0.2080 - val_loss: 0.2359 - val_mae: 0.2359
# Epoch 194/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2149 - mae: 0.2149 - val_loss: 0.1704 - val_mae: 0.1704
# Epoch 195/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1895 - mae: 0.1895 - val_loss: 0.2103 - val_mae: 0.2103
# Epoch 196/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2010 - mae: 0.2010 - val_loss: 0.2274 - val_mae: 0.2274
# Epoch 197/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1959 - mae: 0.1959 - val_loss: 0.2139 - val_mae: 0.2139
# Epoch 198/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1944 - mae: 0.1944 - val_loss: 0.2196 - val_mae: 0.2196
# Epoch 199/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2046 - mae: 0.2046 - val_loss: 0.2097 - val_mae: 0.2097
# Epoch 200/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2041 - mae: 0.2041 - val_loss: 0.1907 - val_mae: 0.1907

# %%
def uv_to_xyz_plane2d(uv, plane_data):

    plane_point = plane_data[:, 0:3]
    basis_u = plane_data[:, 6:9]
    basis_v = plane_data[:, 9:12]

    u = uv[:, 0]
    v = uv[:, 1]

    xyz = (
        plane_point
        + u[:, None] * basis_u
        + v[:, None] * basis_v
    )

    return xyz

# %%
uv_pred_plane2d = model_plane2d.predict(
    X_test_scaled_plane2d
)

xyz_pred_plane2d = uv_to_xyz_plane2d(
    uv_pred_plane2d,
    plane_test_plane2d
)

print("XYZ prediction shape:", xyz_pred_plane2d.shape)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# XYZ prediction shape: (990, 3)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

plt.plot(
    history_plane2d.history["loss"],
    label="Training loss"
)

plt.plot(
    history_plane2d.history["val_loss"],
    label="Validation loss"
)

plt.xlabel("Epoch")
plt.ylabel("MAE (mm)")
plt.title("2D Plane MLP Training and Validation Loss")

plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import r2_score
errors_plane2d = (
    xyz_pred_plane2d - y_test_plane2d
)

absolute_errors_plane2d = np.abs(
    errors_plane2d
)

x_mae_plane2d = np.mean(
    absolute_errors_plane2d[:, 0]
)

y_mae_plane2d = np.mean(
    absolute_errors_plane2d[:, 1]
)

z_mae_plane2d = np.mean(
    absolute_errors_plane2d[:, 2]
)

print("X MAE:", x_mae_plane2d, "mm")
print("Y MAE:", y_mae_plane2d, "mm")
print("Z MAE:", z_mae_plane2d, "mm")
# Out:
# X MAE: 0.1567784993381105 mm
# Y MAE: 0.155472863649275 mm
# Z MAE: 0.14249843299838277 mm

# %%
figures = [
    ("X", 0, x_mae_plane2d),
    ("Y", 1, y_mae_plane2d),
    ("Z", 2, z_mae_plane2d)
]

for coordinate, index, mae_val in figures:

    plt.figure(figsize=(6, 6))

    plt.scatter(
        y_test_plane2d[:, index],
        xyz_pred_plane2d[:, index],
        alpha=0.5
    )

    minimum = min(
        y_test_plane2d[:, index].min(),
        xyz_pred_plane2d[:, index].min()
    )

    maximum = max(
        y_test_plane2d[:, index].max(),
        xyz_pred_plane2d[:, index].max()
    )

    plt.plot(
        [minimum, maximum],
        [minimum, maximum],
        linestyle="--"
    )

    r2_plane2d = r2_score(
        y_test_plane2d[:, index],
        xyz_pred_plane2d[:, index]
    )

    metrics_text = (
        f"Plane 2D:  MAE = {mae_val:.3f} mm,  R² = {r2_plane2d:.3f}"
    )

    plt.text(
        0.05,
        0.05,
        metrics_text,
        transform=plt.gca().transAxes,
        verticalalignment="bottom",
        bbox=dict(
            boxstyle="round",
            alpha=0.85
        )
    )

    plt.xlabel(f"True {coordinate} (mm)")
    plt.ylabel(f"Predicted {coordinate} (mm)")
    plt.title(
        f"2D Plane MLP: True vs Predicted {coordinate}"
    )

    plt.grid(alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
model_errors_plane2d = np.linalg.norm(
    xyz_pred_plane2d - y_test_plane2d,
    axis=1
)

mean_error_plane2d = np.mean(
    model_errors_plane2d
)

median_error_plane2d = np.median(
    model_errors_plane2d
)

std_error_plane2d = np.std(
    model_errors_plane2d
)

max_error_plane2d = np.max(
    model_errors_plane2d
)

print("2D PLANE MLP PERFORMANCE")

print(f"Mean 3D error   : {mean_error_plane2d:.3f} mm")
print(f"Median 3D error : {median_error_plane2d:.3f} mm")
print(f"Std 3D error    : {std_error_plane2d:.3f} mm")
print(f"Maximum error   : {max_error_plane2d:.3f} mm")

print()

print(f"X MAE           : {x_mae_plane2d:.3f} mm")
print(f"Y MAE           : {y_mae_plane2d:.3f} mm")
print(f"Z MAE           : {z_mae_plane2d:.3f} mm")

print()


print("PLANE CONSTRAINT")

plane_points = plane_test_plane2d[:, 0:3]
plane_normals = plane_test_plane2d[:, 3:6]

plane_distances_plane2d = np.abs(
    np.sum(
        (xyz_pred_plane2d - plane_points)
        * plane_normals,
        axis=1
    )
)

print(
    f"Mean plane distance   : "
    f"{np.mean(plane_distances_plane2d):.6f} mm"
)

print(
    f"Median plane distance : "
    f"{np.median(plane_distances_plane2d):.6f} mm"
)

print(
    f"Maximum plane distance: "
    f"{np.max(plane_distances_plane2d):.6f} mm"
)
# Out:
# 2D PLANE MLP PERFORMANCE
# Mean 3D error   : 0.303 mm
# Median 3D error : 0.224 mm
# Std 3D error    : 0.349 mm
# Maximum error   : 6.516 mm
#
# X MAE           : 0.157 mm
# Y MAE           : 0.155 mm
# Z MAE           : 0.142 mm
#
# PLANE CONSTRAINT
# Mean plane distance   : 0.000000 mm
# Median plane distance : 0.000000 mm
# Maximum plane distance: 0.000000 mm

# %%
mean_position_plane2d = np.mean(
    y_train_plane2d,
    axis=0
)

print(
    "Mean annihilation position (train):",
    mean_position_plane2d
)

mean_predictions_plane2d = np.tile(
    mean_position_plane2d,
    (len(y_test_plane2d), 1)
)

mean_errors_plane2d = np.linalg.norm(
    mean_predictions_plane2d - y_test_plane2d,
    axis=1
)

baseline_mean_plane2d = np.mean(
    mean_errors_plane2d
)

baseline_median_plane2d = np.median(
    mean_errors_plane2d
)

print(
    "\nMean-position baseline — mean 3D error:",
    baseline_mean_plane2d,
    "mm"
)

print(
    "Mean-position baseline — median 3D error:",
    baseline_median_plane2d,
    "mm"
)

improvement_plane2d = (
    (baseline_mean_plane2d - mean_error_plane2d)
    / baseline_mean_plane2d
    * 100
)

print(
    f"\n2D plane MLP mean 3D error: "
    f"{mean_error_plane2d:.3f} mm"
)

print(
    f"Baseline mean 3D error: "
    f"{baseline_mean_plane2d:.3f} mm"
)

print(
    f"Improvement over baseline: "
    f"{improvement_plane2d:.1f}%"
)
# Out:
# Mean annihilation position (train): [ 1.82516059  3.00046503 -8.14236138]
#
# Mean-position baseline — mean 3D error: 3.5481860379629215 mm
# Mean-position baseline — median 3D error: 3.6685539241921443 mm
#
# 2D plane MLP mean 3D error: 0.303 mm
# Baseline mean 3D error: 3.548 mm
# Improvement over baseline: 91.5%

# %%
fig, axes = plt.subplots(1, 3, figsize=(17, 5))
projections = [(0, 1, "X", "Y"), (0, 2, "X", "Z"), (1, 2, "Y", "Z")]

for ax, (i, j, xname, yname) in zip(axes, projections):
    ax.scatter(y_test_plane2d[:, i], y_test_plane2d[:, j], alpha=0.5, label="True")
    ax.scatter(xyz_pred_plane2d[:, i], xyz_pred_plane2d[:, j], alpha=0.5, label="Predicted")
    ax.set_xlabel(f"{xname} (mm)")
    ax.set_ylabel(f"{yname} (mm)")
    ax.set_title(f"{xname}-{yname} Projection")
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.show()

# %%
for coordinate, index in [
    ("X", 0),
    ("Y", 1),
    ("Z", 2)
]:

    plt.figure(figsize=(8, 5))

    plt.hist(
        errors_plane2d[:, index],
        bins=30
    )

    plt.axvline(
        0,
        linestyle="--"
    )

    plt.xlabel(f"{coordinate} residual (mm)")
    plt.ylabel("Number of events")
    plt.title(
        f"2D Plane MLP {coordinate} Reconstruction Residuals"
    )

    plt.grid(alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
n_events = min(6, len(X_test_plane2d))

fig = plt.figure(figsize=(15, 10))

for i in range(n_events):
    ax = fig.add_subplot(2, 3, i + 1, projection="3d")

    # Use X_test_plane2d for features
    hits = np.array([X_test_plane2d[i, 0:3], X_test_plane2d[i, 4:7], X_test_plane2d[i, 8:11]])
    # Use y_test_plane2d for true positions
    true_pos = y_test_plane2d[i]
    # Use xyz_pred_plane2d for predicted positions
    pred_pos = xyz_pred_plane2d[i]

    ax.scatter(hits[:, 0], hits[:, 1], hits[:, 2], s=80, marker="o", label="Gamma hits")
    ax.scatter(*true_pos, s=100, marker="*", label="True annihilation")
    ax.scatter(*pred_pos, s=100, marker="X", label="MLP prediction")

    for hit in hits:
        ax.plot([true_pos[0], hit[0]], [true_pos[1], hit[1]], [true_pos[2], hit[2]],
                linestyle="--", alpha=0.5)

    ax.plot([true_pos[0], pred_pos[0]], [true_pos[1], pred_pos[1]], [true_pos[2], pred_pos[2]],
            linestyle=":", linewidth=2)

    error = np.linalg.norm(pred_pos - true_pos)
    ax.set_title(f"Event {i+1}\nReconstruction error = {error:.2f} mm")
    ax.set_xlabel("X (mm)")
    ax.set_ylabel("Y (mm)")
    ax.set_zlabel("Z (mm)")

handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper center", ncol=3)

plt.tight_layout()
plt.show()
